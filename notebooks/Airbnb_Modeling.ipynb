# %% [markdown]
# This notebook contains all the modeling steps after the feature selection one

# %%
# !pip install scikit-optimize
# Out:
# Requirement already satisfied: scikit-optimize in /usr/local/lib/python3.6/dist-packages (0.7.1)
# Requirement already satisfied: numpy in /tensorflow-2.1.0/python3.6 (from scikit-optimize) (1.18.1)
# Requirement already satisfied: scipy>=0.14.0 in /tensorflow-2.1.0/python3.6 (from scikit-optimize) (1.4.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (0.14.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (0.22.1)
# Requirement already satisfied: pyaml in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (19.12.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from pyaml->scikit-optimize) (3.13)

# %%
# %tensorflow_version 2.x
import os
os.environ['TF_DETERMINISTIC_OPS'] = '1'

# %%
import numpy as np
import joblib
import pandas as pd
import dill

from functools import partial

from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.calibration import CalibratedClassifierCV
from sklearn.compose import make_column_transformer
from sklearn.ensemble import StackingClassifier
from sklearn.preprocessing import StandardScaler, LabelBinarizer, LabelEncoder
from sklearn.metrics import log_loss, ndcg_score
from sklearn.utils import resample, check_X_y, check_array, check_random_state
from sklearn.utils.multiclass import type_of_target
from sklearn.utils._testing import SkipTest

from scipy.optimize import minimize

from skopt import forest_minimize, gp_minimize
from skopt.plots import plot_objective
from skopt.space import Real, Integer
from skopt.utils import use_named_args


from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.callbacks import (
    ModelCheckpoint, EarlyStopping, TerminateOnNaN
)
from tensorflow.keras.layers import (
    Dense, Dropout, Activation, BatchNormalization, ELU
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2


import xgboost
from xgboost import XGBClassifier

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def preprocess_x(x_train, x_val):
  ohe_feats = ['gender', 'signup_method', 'signup_flow', 'language', 
              'affiliate_channel', 'affiliate_provider', 
              'first_affiliate_tracked', 'signup_app', 
              'first_device_type', 'first_browser']

  cat_strings = ohe_feats + ['age_interv', 'tfa_', 'dac_', 'booked', 'has_session']
  cat_features = [idx for idx, x in enumerate(x_train.columns) for string in cat_strings \
                  if string in x and 'action' not in x and 'epochs' not in x and 'msecs' not in x]
  
  num_features = [col for col in x_train.columns if col not in cat_features]
  
  ss = StandardScaler()
  preprocessor = make_column_transformer((ss, num_features), 
                                         remainder='passthrough')
  X_train = preprocessor.fit_transform(x_train)
  X_val = preprocessor.transform(x_val)
  return X_train, X_val


def plot_metrics(history):
  metrics =  ['loss', 'sparse_categorical_accuracy']
  plt.figure(figsize=(10, 10))
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch,  history.history[metric], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric], 
            linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    else:
      plt.ylim([0,1])
    plt.legend()

# %%
base_path = '/content/drive/My Drive/AML - AIRBNB/'
X_train_path = os.path.join(base_path, 'X_train_v2.pkl')
X_val_path = os.path.join(base_path, 'X_val.pkl')
y_train_path = os.path.join(base_path, 'y_train_v2.pkl')
y_val_path = os.path.join(base_path, 'y_val.pkl')

xgb_features_path = os.path.join(base_path, 'xgboost_features.pkl')

models_path = os.path.join(base_path, 'models')

# %%
X_train = pd.read_pickle(X_train_path)
X_val = pd.read_pickle(X_val_path)

y_train = pd.read_pickle(y_train_path)
y_val = pd.read_pickle(y_val_path)

# %%
xgb_features = pd.read_pickle(xgb_features_path)

# %%
xgb_features = X_train.columns.isin(xgb_features)

# %%
X_train, X_val = preprocess_x(X_train, X_val)

# %% [markdown]
# # MLP
#
# ---

# %%
def get_nn(X, y, neurons_1 = 256, neurons_2 = 128, neurons_3 = 64, l2_1 = 0.01,
           l2_2 = 0.01, lr=0.001):
  n_classes = len(np.unique(y))
  nn = Sequential()
  nn.add(Dense(neurons_1, input_dim=X.shape[1], kernel_regularizer=l2(l2_1)))
  nn.add(ELU())
  nn.add(BatchNormalization())
  nn.add(Dropout(0.5))    
  nn.add(Dense(neurons_2, kernel_regularizer=l2(l2_2)))
  nn.add(ELU())
  nn.add(BatchNormalization())
  nn.add(Dropout(0.4))    
  nn.add(Dense(neurons_3))
  nn.add(ELU())
  nn.add(BatchNormalization())
  nn.add(Dropout(0.4))   
  nn.add(Dense(n_classes))
  nn.add(Activation('softmax'))
  nn.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(lr=lr),
              metrics=['sparse_categorical_accuracy',
                      'sparse_top_k_categorical_accuracy'])
  return nn

# %%
model = get_nn(X_train[:, xgb_features], y_train)

model.fit(X_train[:, xgb_features], y_train, epochs=500, batch_size=32, 
      validation_data=(X_val[:, xgb_features], y_val), verbose=2,
      callbacks=[EarlyStopping(patience=10, restore_best_weights=True)])

# %%
ndcg_score(LabelBinarizer().fit_transform(y_val), 
           model.predict_proba(X_val[:,xgb_features]))
# Out:
# 0.8719705025340047

# %%
paramnames_nn = ['neurons_1', 'neurons_2', 'neurons_3', 'l2_1', 'l2_2', 'lr']

nn_space = [Integer(16, 1000, name='neurons_1'),
            Integer(16, 1000, name='neurons_2'),
            Integer(16, 1000, name='neurons_3'),
            Real(0.00001, 1, 'uniform', name='l2_1'), 
            Real(0.00001, 1, 'uniform', name='l2_2'),
            Real(0.0001, 0.1, 'uniform', name='lr')]

# %% [markdown]
# # XGBoost
#
# ---

# %%
LR_START = 0.1
LR_MIN = 0.008

# %%
def learning_rate_decay(boosting_round, num_boost_round, lr_start,
                        lr_min, lr_decay):
    learning_rate_start = lr_start
    learning_rate_min = lr_min
    lr_decay = lr_decay
    lr = learning_rate_start * np.power(lr_decay, boosting_round)
    return max(learning_rate_min, lr)


def get_xgb(num_class, lr_start=LR_START, lr_min=LR_MIN, lr_decay=0.98, 
            subsample_perc=1, lambda_reg=1):
  decaying_lr = partial(learning_rate_decay, lr_start=lr_start, lr_min=lr_min,
                        lr_decay=lr_decay)
  xgb = XGBClassifier(max_depth=7, n_estimators=1000, num_class=num_class,
                    objective='multi:softprob', gamma=0, min_child_weight=1,
                    max_delta_step=0, subsample=subsample_perc,
                    colsample_bytree=1,
                    missing=-1,
                    colsample_by_level=1,
                    reg_alpha=0, reg_lambda=lambda_reg, 
                    seed=42, tree_method = "gpu_hist",
                    callbacks=[xgboost.callback.reset_learning_rate(decaying_lr)]) 
  return xgb

# %%
xgb = get_xgb(12)
xgb.fit(X_train[:,xgb_features], y_train,
        eval_set=[(X_val[:, xgb_features], y_val)],
        eval_metric=['merror', 'mlogloss'],
        early_stopping_rounds=10, verbose=1)
# Out:
# [0]	validation_0-merror:0.360156	validation_0-mlogloss:2.14361
# Multiple eval metrics have been passed: 'validation_0-mlogloss' will be used for early stopping.
#
# Will train until validation_0-mlogloss hasn't improved in 10 rounds.
# [1]	validation_0-merror:0.350261	validation_0-mlogloss:1.95117
# [2]	validation_0-merror:0.344696	validation_0-mlogloss:1.81457
# [3]	validation_0-merror:0.343815	validation_0-mlogloss:1.70737
# [4]	validation_0-merror:0.341847	validation_0-mlogloss:1.62155
# [5]	validation_0-merror:0.337781	validation_0-mlogloss:1.55067
# [6]	validation_0-merror:0.336975	validation_0-mlogloss:1.48867
# [7]	validation_0-merror:0.335026	validation_0-mlogloss:1.43783
# [8]	validation_0-merror:0.332215	validation_0-mlogloss:1.39273
# [9]	validation_0-merror:0.332196	validation_0-mlogloss:1.35298
# [10]	validation_0-merror:0.33244	validation_0-mlogloss:1.31888
# [11]	validation_0-merror:0.33304	validation_0-mlogloss:1.29029
# [12]	validation_0-merror:0.331653	validation_0-mlogloss:1.26344
# [13]	validation_0-merror:0.333115	validation_0-mlogloss:1.24045
# [14]	validation_0-merror:0.33259	validation_0-mlogloss:1.21879
# [15]	validation_0-merror:0.331166	validation_0-mlogloss:1.20023
# [16]	validation_0-merror:0.331203	validation_0-mlogloss:1.18267
# [17]	validation_0-merror:0.32753	validation_0-mlogloss:1.16549
# [18]	validation_0-merror:0.328074	validation_0-mlogloss:1.15282
# [19]	validation_0-merror:0.32768	validation_0-mlogloss:1.13961
# [20]	validation_0-merror:0.326537	validation_0-mlogloss:1.12794
# [21]	validation_0-merror:0.327793	validation_0-mlogloss:1.11918
# [22]	validation_0-merror:0.324569	validation_0-mlogloss:1.10225
# [23]	validation_0-merror:0.324251	validation_0-mlogloss:1.09445
# [24]	validation_0-merror:0.321103	validation_0-mlogloss:1.07824
# [25]	validation_0-merror:0.321552	validation_0-mlogloss:1.07113
# [26]	validation_0-merror:0.320878	validation_0-mlogloss:1.06209
# [27]	validation_0-merror:0.321627	validation_0-mlogloss:1.05668
# [28]	validation_0-merror:0.322002	validation_0-mlogloss:1.04987
# [29]	validation_0-merror:0.321609	validation_0-mlogloss:1.04533
# [30]	validation_0-merror:0.322264	validation_0-mlogloss:1.04121
# [31]	validation_0-merror:0.321421	validation_0-mlogloss:1.03635
# [32]	validation_0-merror:0.321721	validation_0-mlogloss:1.0326
# [33]	validation_0-merror:0.320784	validation_0-mlogloss:1.02738
# [34]	validation_0-merror:0.320728	validation_0-mlogloss:1.0234
# [35]	validation_0-merror:0.319472	validation_0-mlogloss:1.0178
# [36]	validation_0-merror:0.319416	validation_0-mlogloss:1.01502
# [37]	validation_0-merror:0.318517	validation_0-mlogloss:1.0112
# [38]	validation_0-merror:0.316961	validation_0-mlogloss:1.00154
# [39]	validation_0-merror:0.316118	validation_0-mlogloss:0.997783
# [40]	validation_0-merror:0.314956	validation_0-mlogloss:0.990511
# [41]	validation_0-merror:0.31312	validation_0-mlogloss:0.981578
# [42]	validation_0-merror:0.310758	validation_0-mlogloss:0.973415
# [43]	validation_0-merror:0.308941	validation_0-mlogloss:0.965528
# [44]	validation_0-merror:0.307704	validation_0-mlogloss:0.960938
# [45]	validation_0-merror:0.306242	validation_0-mlogloss:0.953628
# [46]	validation_0-merror:0.305586	validation_0-mlogloss:0.949161
# [47]	validation_0-merror:0.304443	validation_0-mlogloss:0.943699
# [48]	validation_0-merror:0.302494	validation_0-mlogloss:0.937993
# [49]	validation_0-merror:0.302532	validation_0-mlogloss:0.936456
# [50]	validation_0-merror:0.301501	validation_0-mlogloss:0.932621
# [51]	validation_0-merror:0.300433	validation_0-mlogloss:0.927344
# [52]	validation_0-merror:0.30077	validation_0-mlogloss:0.927613
# [53]	validation_0-merror:0.299477	validation_0-mlogloss:0.924246
# [54]	validation_0-merror:0.298896	validation_0-mlogloss:0.919958
# [55]	validation_0-merror:0.297697	validation_0-mlogloss:0.91695
# [56]	validation_0-merror:0.29616	validation_0-mlogloss:0.91371
# [57]	validation_0-merror:0.295617	validation_0-mlogloss:0.911203
# [58]	validation_0-merror:0.294136	validation_0-mlogloss:0.907565
# [59]	validation_0-merror:0.292431	validation_0-mlogloss:0.903807
# [60]	validation_0-merror:0.291026	validation_0-mlogloss:0.900034
# [61]	validation_0-merror:0.290576	validation_0-mlogloss:0.898595
# [62]	validation_0-merror:0.288964	validation_0-mlogloss:0.895144
# [63]	validation_0-merror:0.288496	validation_0-mlogloss:0.893699
# [64]	validation_0-merror:0.287484	validation_0-mlogloss:0.891024
# [65]	validation_0-merror:0.286472	validation_0-mlogloss:0.887994
# [66]	validation_0-merror:0.285422	validation_0-mlogloss:0.885565
# [67]	validation_0-merror:0.285179	validation_0-mlogloss:0.884857
# [68]	validation_0-merror:0.284879	validation_0-mlogloss:0.88397
# [69]	validation_0-merror:0.284279	validation_0-mlogloss:0.882638
# [70]	validation_0-merror:0.283811	validation_0-mlogloss:0.880053
# [71]	validation_0-merror:0.283698	validation_0-mlogloss:0.880132
# [72]	validation_0-merror:0.282462	validation_0-mlogloss:0.877478
# [73]	validation_0-merror:0.282162	validation_0-mlogloss:0.874541
# [74]	validation_0-merror:0.281675	validation_0-mlogloss:0.873327
# [75]	validation_0-merror:0.280456	validation_0-mlogloss:0.871735
# [76]	validation_0-merror:0.280063	validation_0-mlogloss:0.870213
# [77]	validation_0-merror:0.280044	validation_0-mlogloss:0.86931
# [78]	validation_0-merror:0.280344	validation_0-mlogloss:0.869699
# [79]	validation_0-merror:0.279182	validation_0-mlogloss:0.867376
# [80]	validation_0-merror:0.27862	validation_0-mlogloss:0.865172
# [81]	validation_0-merror:0.278358	validation_0-mlogloss:0.864242
# [82]	validation_0-merror:0.277046	validation_0-mlogloss:0.86166
# [83]	validation_0-merror:0.276765	validation_0-mlogloss:0.860681
# [84]	validation_0-merror:0.276877	validation_0-mlogloss:0.860351
# [85]	validation_0-merror:0.276353	validation_0-mlogloss:0.859008
# [86]	validation_0-merror:0.275059	validation_0-mlogloss:0.85656
# [87]	validation_0-merror:0.274535	validation_0-mlogloss:0.856154
# [88]	validation_0-merror:0.274048	validation_0-mlogloss:0.853082
# [89]	validation_0-merror:0.273467	validation_0-mlogloss:0.851367
# [90]	validation_0-merror:0.272511	validation_0-mlogloss:0.848129
# [91]	validation_0-merror:0.27163	validation_0-mlogloss:0.846337
# [92]	validation_0-merror:0.271049	validation_0-mlogloss:0.84405
# [93]	validation_0-merror:0.270487	validation_0-mlogloss:0.842582
# [94]	validation_0-merror:0.27	validation_0-mlogloss:0.842028
# [95]	validation_0-merror:0.269775	validation_0-mlogloss:0.839807
# [96]	validation_0-merror:0.269569	validation_0-mlogloss:0.839675
# [97]	validation_0-merror:0.269494	validation_0-mlogloss:0.838646
# [98]	validation_0-merror:0.26895	validation_0-mlogloss:0.838254
# [99]	validation_0-merror:0.268463	validation_0-mlogloss:0.835877
# [100]	validation_0-merror:0.268969	validation_0-mlogloss:0.836434
# [101]	validation_0-merror:0.268613	validation_0-mlogloss:0.835673
# [102]	validation_0-merror:0.267845	validation_0-mlogloss:0.833627
# [103]	validation_0-merror:0.267264	validation_0-mlogloss:0.83161
# [104]	validation_0-merror:0.266852	validation_0-mlogloss:0.830497
# [105]	validation_0-merror:0.267283	validation_0-mlogloss:0.830635
# [106]	validation_0-merror:0.266833	validation_0-mlogloss:0.830164
# [107]	validation_0-merror:0.266421	validation_0-mlogloss:0.828037
# [108]	validation_0-merror:0.266514	validation_0-mlogloss:0.82786
# [109]	validation_0-merror:0.266364	validation_0-mlogloss:0.82747
# [110]	validation_0-merror:0.266121	validation_0-mlogloss:0.827534
# [111]	validation_0-merror:0.266421	validation_0-mlogloss:0.827781
# [112]	validation_0-merror:0.265971	validation_0-mlogloss:0.826945
# [113]	validation_0-merror:0.265221	validation_0-mlogloss:0.826469
# [114]	validation_0-merror:0.265128	validation_0-mlogloss:0.825861
# [115]	validation_0-merror:0.265615	validation_0-mlogloss:0.825704
# [116]	validation_0-merror:0.265071	validation_0-mlogloss:0.824368
# [117]	validation_0-merror:0.264884	validation_0-mlogloss:0.824151
# [118]	validation_0-merror:0.264734	validation_0-mlogloss:0.823987
# [119]	validation_0-merror:0.264303	validation_0-mlogloss:0.823572
# [120]	validation_0-merror:0.26434	validation_0-mlogloss:0.823684
# [121]	validation_0-merror:0.264678	validation_0-mlogloss:0.823817
# [122]	validation_0-merror:0.264266	validation_0-mlogloss:0.823599
# [123]	validation_0-merror:0.264284	validation_0-mlogloss:0.82216
# [124]	validation_0-merror:0.264116	validation_0-mlogloss:0.822161
# [125]	validation_0-merror:0.264153	validation_0-mlogloss:0.822395
# [126]	validation_0-merror:0.264528	validation_0-mlogloss:0.822713
# [127]	validation_0-merror:0.264453	validation_0-mlogloss:0.82302
# [128]	validation_0-merror:0.263947	validation_0-mlogloss:0.821746
# [129]	validation_0-merror:0.263891	validation_0-mlogloss:0.821848
# [130]	validation_0-merror:0.263891	validation_0-mlogloss:0.822081
# [131]	validation_0-merror:0.263666	validation_0-mlogloss:0.821823
# [132]	validation_0-merror:0.263516	validation_0-mlogloss:0.820749
# [133]	validation_0-merror:0.263422	validation_0-mlogloss:0.821057
# [134]	validation_0-merror:0.263572	validation_0-mlogloss:0.820387
# [135]	validation_0-merror:0.263478	validation_0-mlogloss:0.820306
# [136]	validation_0-merror:0.263329	validation_0-mlogloss:0.820528
# [137]	validation_0-merror:0.26316	validation_0-mlogloss:0.820197
# [138]	validation_0-merror:0.263553	validation_0-mlogloss:0.820143
# [139]	validation_0-merror:0.263197	validation_0-mlogloss:0.819977
# [140]	validation_0-merror:0.263347	validation_0-mlogloss:0.82017
# [141]	validation_0-merror:0.263553	validation_0-mlogloss:0.82017
# [142]	validation_0-merror:0.263478	validation_0-mlogloss:0.82002
# [143]	validation_0-merror:0.26346	validation_0-mlogloss:0.819391
# [144]	validation_0-merror:0.263291	validation_0-mlogloss:0.819587
# [145]	validation_0-merror:0.263216	validation_0-mlogloss:0.819079
# [146]	validation_0-merror:0.262823	validation_0-mlogloss:0.818449
# [147]	validation_0-merror:0.263179	validation_0-mlogloss:0.81913
# [148]	validation_0-merror:0.263197	validation_0-mlogloss:0.819509
# [149]	validation_0-merror:0.263272	validation_0-mlogloss:0.819778
# [150]	validation_0-merror:0.263516	validation_0-mlogloss:0.81969
# [151]	validation_0-merror:0.26331	validation_0-mlogloss:0.81974
# [152]	validation_0-merror:0.263497	validation_0-mlogloss:0.819564
# [153]	validation_0-merror:0.262691	validation_0-mlogloss:0.818533
# [154]	validation_0-merror:0.26301	validation_0-mlogloss:0.818761
# [155]	validation_0-merror:0.26286	validation_0-mlogloss:0.818606
# [156]	validation_0-merror:0.262823	validation_0-mlogloss:0.818633
# Stopping. Best iteration:
# [146]	validation_0-merror:0.262823	validation_0-mlogloss:0.818449
# XGBClassifier(base_score=0.5, booster='gbtree',
#               callbacks=[<function reset_learning_rate.<locals>.callback at 0x7f046a2b3b70>],
#               colsample_by_level=1, colsample_bylevel=1, colsample_bynode=1,
#               colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#               max_depth=7, min_child_weight=1, missing=-1, n_estimators=1000,
#               n_jobs=1, nthread=None, num_class=12, objective='multi:softprob',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               seed=42, silent=None, subsample=1, tree_method='gpu_hist',
#               verbosity=1)

# %%
ndcg_score(LabelBinarizer().fit_transform(y_val), 
           xgb.predict_proba(X_val[:,xgb_features]))
# Out:
# 0.8592073125985906

# %%
paramnames_xgb = ['lr_start', 'lr_min', 'lr_decay', 'subsample_perc', 'lambda']

xgb_space = [Real(0.05, 0.08, 'uniform', name='lr_start'),
             Real(0.0005, 0.05, 'uniform', name='lr_min'),
             Real(0.93, 0.99, 'uniform', name='lr_decay'),
             Real(0.6, 1, 'uniform', name='subsample_perc'), 
             Real(0.0001, 1, 'uniform', name='lambda_reg')]

# %% [markdown]
# # ENSEMBLING (WITH HPO INTEGRATION)
#
# ---

# %% [markdown]
# The EnsembleClasifier class is a sklearn-compatible estimator that implements the fitting of the base models (via the *__fit_nn* and *__fit_xgb* methods) as well as the fitting of the ensembler (via the *_fit_ensembler* method). The public *fit* method calss each of the aforementioned methods one by one. It also has a built-in HPO feature which can be activated through a boolean flag.
#
# This class implements the first ensembler presented in the report.

# %%
class EnsembleClassifier(BaseEstimator, ClassifierMixin):
  def __init__(self, EPOCHS=500, BATCHSIZE=64, BOOTSTRAP_ITER=5, 
               load_models=False, save_models=False,
               random_state=42, hpo=False,):
    super(BaseEstimator, self).__init__()
    self.EPOCHS = EPOCHS
    self.BATCHSIZE = BATCHSIZE
    self.BOOTSTRAP_ITER = BOOTSTRAP_ITER
    self.load_models = load_models
    self.save_models = save_models
    self.random_state = random_state
    self.hpo = hpo
    self.__hpo_nn = use_named_args(nn_space)(self.__hpo_nn)
    self.__hpo_xgb = use_named_args(xgb_space)(self.__hpo_xgb)


  @staticmethod
  def _more_tags():
    return {'multioutput_only': True,
            'requires_fit': True}
  

  @staticmethod
  def objective_fun(w, X, y, n_class):
    predsize = len(w)
    w_range = np.arange(predsize) % n_class 
    for i in range(n_class): 
        w[w_range==i] = w[w_range==i] / np.sum(w[w_range==i])
        
    sol = np.zeros((X.shape[0], n_class))
    for idx in range(predsize):
        sol[:, idx % n_class] += X[:, idx] * w[idx]
    if np.isnan(sol).any():
      return np.inf
    ll = log_loss(y, sol)
    return ll


  def fit(self, X, y, **kwargs):
    X = check_array(X, dtype=[np.int_, np.intc, np.single, 
                              np.double, np.longdouble,
                              np.uint, np.int32, np.int64,
                              np.float32, np.float64])
    y = check_array(y, dtype = np.int_, ensure_2d=False)
    self.random_state_ = self.random_state
    self.X_train_ = X
    self.y_train_ = y.ravel()
    self.n_classes_ = len(np.unique(self.y_train_))
    self.classes_  = list(range(self.n_classes_))
    X_val = kwargs.get('X_val')
    y_val = kwargs.get('y_val')

    if X_val is not None and y_val is not None:
      self.X_val_ = X_val
      self.y_val_ = y_val
      self.val_data_ = (self.X_val_, self.y_val_)
      self.xgb_val_data_ = [self.val_data_]
      self.xgb_metrics_ = ['merror', 'mlogloss']
      self.xgb_es_ = 50
    else:
      self.X_val_ = None
      self.y_val_ = None
      self.val_data_ = None
      self.xgb_val_data_ = None
      self.xgb_metrics_ = None
      self.xgb_es_ = None
    
    nn_params = {}
    xgb_params = {}
    if self.hpo:
      print('ENTERING HPO...')
      xgb_params = self.__xgb_hpo_wrapper() 
      nn_params = self.__nn_hpo_wrapper()

    self.nn_models_ = self.__fit_nn(self.save_models, **nn_params)
    self.xgb_models_ = self.__fit_xgb(self.save_models, **xgb_params)

    print("FITTING ENSEMBLER...")
    self._fit_ensembler()
    return self

  def __fit_nn(self, save, **kwargs):
    nn_models_ = []
    for idx in range(self.BOOTSTRAP_ITER):
      term = TerminateOnNaN()
      self.nn_callbacks_ = [term]

      if self.X_val_ is not None and self.y_val_ is not None:
        nn_es = EarlyStopping(monitor='val_loss', patience=10, verbose=1, 
                                restore_best_weights=True) 
        self.nn_callbacks_.append(nn_es)

      self.random_state_ += 1
      random_state = check_random_state(self.random_state_)
      X, y = resample(self.X_train_, self.y_train_, random_state=random_state)
      nnpath = os.path.join(models_path, f'nn_{idx}.hdf5')
      
      if os.path.isfile(nnpath) and self.load_models:
        print(f"LOADING NN {idx}...\n\n")
        nn = load_model(nnpath)
      
      else:
        print(f"FITTING NN ON BOOTSTRAP {idx}\n\n")
        nn = get_nn(self.X_train_, self.y_train_, **kwargs)
        nn.fit(X, y, epochs=self.EPOCHS, batch_size=self.BATCHSIZE, 
              validation_data=self.val_data_, verbose=2,
              callbacks=self.nn_callbacks_)
        if save:
          nn.save(nnpath)
    
      nn_models_.append(nn)
    return nn_models_

  def __fit_xgb(self, save, **kwargs):
    xgb_models_ = []
    for idx in range(self.BOOTSTRAP_ITER):
      self.random_state_ += 1
      random_state = check_random_state(self.random_state_)
      X, y = resample(self.X_train_, self.y_train_, random_state=random_state)
      xgb = get_xgb(self.n_classes_, **kwargs)
      xgb_path = os.path.join(models_path, f'xgb_{idx}.pkl')

      if os.path.isfile(xgb_path) and self.load_models:
        print(f"LOADING XGB {idx}...\n\n")
        with open(xgb_path, 'rb') as f:
          xgb = dill.load(f)
      
      else:
        print(f"FITTING XGB ON BOOTSTRAP {idx}\n\n")
        xgb.fit(X, y, eval_set=self.xgb_val_data_,
                eval_metric=self.xgb_metrics_,
                early_stopping_rounds=self.xgb_es_, verbose=1)
        if save:
          with open(xgb_path, 'wb') as f:
            dill.dump(xgb, f)

      xgb_models_.append(xgb)
    return xgb_models_


  def __hpo_obj(self, models):
    print('EVALUATING NDCG FOR HPO..')
    scores = []
    for model in models:
      preds = model.predict_proba(self.X_val_)
      score = ndcg_score(self.T_val_, preds, k=5, ignore_ties=True)
      scores.append(score)
    return -np.mean(scores)
  

  def __hpo_nn(self, **kwargs):
    nns = self.__fit_nn(save=False, **kwargs)
    return self.__hpo_obj(nns)


  def __nn_hpo_wrapper(self):
    self.T_val_ = self._convert_y_for_testing(self.y_val_)
    res = forest_minimize(self.__hpo_nn, dimensions=nn_space,
                        n_calls=15, n_random_starts=5,
                        acq_func="LCB", random_state=self.random_state)
    best = res.x
    self.nn_bestseen_ = -np.minimum.accumulate(res.func_vals)
    self.nn_best_conf_ = dict(zip(paramnames_nn, best))
    return self.nn_best_conf_


  def __hpo_xgb(self, **kwargs):
    xgbs = self.__fit_xgb(save=False, **kwargs)
    return self.__hpo_obj(xgbs)


  def __xgb_hpo_wrapper(self):
    self.T_val_ = self._convert_y_for_testing(self.y_val_)
    res = gp_minimize(self.__hpo_xgb, dimensions=xgb_space,
                      n_calls=15, n_random_starts=5,
                      acq_func="LCB", random_state=self.random_state)
    best = res.x
    self.xgb_bestseen_ = -np.minimum.accumulate(res.func_vals)
    self.xgb_best_conf_ = dict(zip(paramnames_xgb, best))
    return self.xgb_best_conf_


  def get_prediction_matrix(self, X):
    print("Computing preliminary predictions...")
    predictions = np.empty((X.shape[0], 0))
    for model in self.nn_models_ + self.xgb_models_:
      modelpreds = model.predict_proba(X)
      predictions = np.hstack((predictions, modelpreds))
    return predictions


  def _fit_ensembler(self):
    X_probs = self.get_prediction_matrix(self.X_train_)
    x0 = np.random.uniform(size = self.n_classes_ * len(self.nn_models_ + self.xgb_models_))
    bounds = [(0,1)]*len(x0)   
    res = minimize(self.objective_fun, 
                   x0, 
                   args=(X_probs, self.y_train_, self.n_classes_), 
                   method='L-BFGS-B', 
                   bounds=bounds
                  )
    self.w_ = res.x


  def predict(self, X):
    X = check_array(X)
    pred_probs = self.get_prediction_matrix(X)
    y_pred = np.zeros((X.shape[0], self.n_classes_))
    for i in range(len(self.w_)):
        y_pred[:, i % self.n_classes_] += pred_probs[:, i] * self.w_[i]   
    return y_pred 

    
  def predict_proba(self, X):
    return self.predict(X)
  

  def _convert_y_for_testing(self, y):
    lb = LabelBinarizer()
    lb.fit(range(self.n_classes_))
    T = lb.transform(y)
    return T

  def score(self, X, y):
    y = check_array(y, dtype = np.int_, ensure_2d=False).ravel()
    if type_of_target(y) == 'binary':
      raise SkipTest
    elif y.ndim < 2:
      T = self._convert_y_for_testing(y)
    else:
      T = y
    preds = self.predict(X)
    return ndcg_score(T, preds, k=min(self.n_classes_, 5), ignore_ties=True)

# %%
ens = EnsembleClassifier(BOOTSTRAP_ITER=10, load_models=False,
                         save_models=True)

# %%
ens.fit(X_train[:, xgb_features], y_train, 
        X_val=X_val[:, xgb_features], 
        y_val=y_val)
# Out:
# FITTING NN ON BOOTSTRAP 0
#
#
# Train on 49988 samples, validate on 53363 samples
# Epoch 1/500
# 49988/49988 - 6s - loss: 3.3653 - sparse_categorical_accuracy: 0.3998 - sparse_top_k_categorical_accuracy: 0.7721 - val_loss: 1.4209 - val_sparse_categorical_accuracy: 0.6308 - val_sparse_top_k_categorical_accuracy: 0.8137
# Epoch 2/500
# 49988/49988 - 5s - loss: 1.8292 - sparse_categorical_accuracy: 0.4560 - sparse_top_k_categorical_accuracy: 0.8248 - val_loss: 1.3662 - val_sparse_categorical_accuracy: 0.7140 - val_sparse_top_k_categorical_accuracy: 0.8309
# Epoch 3/500
# 49988/49988 - 5s - loss: 1.7776 - sparse_categorical_accuracy: 0.4637 - sparse_top_k_categorical_accuracy: 0.8269 - val_loss: 1.4876 - val_sparse_categorical_accuracy: 0.6011 - val_sparse_top_k_categorical_accuracy: 0.8160
# Epoch 4/500
# 49988/49988 - 5s - loss: 1.7584 - sparse_categorical_accuracy: 0.4649 - sparse_top_k_categorical_accuracy: 0.8326 - val_loss: 1.2687 - val_sparse_categorical_accuracy: 0.6494 - val_sparse_top_k_categorical_accuracy: 0.8074
# Epoch 5/500
# 49988/49988 - 5s - loss: 1.7599 - sparse_categorical_accuracy: 0.4635 - sparse_top_k_categorical_accuracy: 0.8333 - val_loss: 1.5200 - val_sparse_categorical_accuracy: 0.6059 - val_sparse_top_k_categorical_accuracy: 0.7873
# Epoch 6/500
# 49988/49988 - 5s - loss: 1.7400 - sparse_categorical_accuracy: 0.4678 - sparse_top_k_categorical_accuracy: 0.8359 - val_loss: 1.1782 - val_sparse_categorical_accuracy: 0.6841 - val_sparse_top_k_categorical_accuracy: 0.8420
# Epoch 7/500
# 49988/49988 - 5s - loss: 1.6995 - sparse_categorical_accuracy: 0.4761 - sparse_top_k_categorical_accuracy: 0.8393 - val_loss: 1.1297 - val_sparse_categorical_accuracy: 0.6728 - val_sparse_top_k_categorical_accuracy: 0.8650
# Epoch 8/500
# 49988/49988 - 5s - loss: 1.7000 - sparse_categorical_accuracy: 0.4757 - sparse_top_k_categorical_accuracy: 0.8397 - val_loss: 1.1165 - val_sparse_categorical_accuracy: 0.6627 - val_sparse_top_k_categorical_accuracy: 0.8706
# Epoch 9/500
# 49988/49988 - 5s - loss: 1.7082 - sparse_categorical_accuracy: 0.4769 - sparse_top_k_categorical_accuracy: 0.8375 - val_loss: 1.1540 - val_sparse_categorical_accuracy: 0.6742 - val_sparse_top_k_categorical_accuracy: 0.8534
# Epoch 10/500
# 49988/49988 - 5s - loss: 1.6835 - sparse_categorical_accuracy: 0.4796 - sparse_top_k_categorical_accuracy: 0.8414 - val_loss: 1.0613 - val_sparse_categorical_accuracy: 0.7370 - val_sparse_top_k_categorical_accuracy: 0.8931
# Epoch 11/500
# 49988/49988 - 5s - loss: 1.6866 - sparse_categorical_accuracy: 0.4798 - sparse_top_k_categorical_accuracy: 0.8405 - val_loss: 1.1567 - val_sparse_categorical_accuracy: 0.6640 - val_sparse_top_k_categorical_accuracy: 0.8589
# Epoch 12/500
# 49988/49988 - 5s - loss: 1.6682 - sparse_categorical_accuracy: 0.4855 - sparse_top_k_categorical_accuracy: 0.8432 - val_loss: 1.4457 - val_sparse_categorical_accuracy: 0.6251 - val_sparse_top_k_categorical_accuracy: 0.8399
# Epoch 13/500
# 49988/49988 - 5s - loss: 1.6761 - sparse_categorical_accuracy: 0.4823 - sparse_top_k_categorical_accuracy: 0.8426 - val_loss: 1.3593 - val_sparse_categorical_accuracy: 0.7258 - val_sparse_top_k_categorical_accuracy: 0.8345
# Epoch 14/500
# 49988/49988 - 5s - loss: 1.7157 - sparse_categorical_accuracy: 0.4754 - sparse_top_k_categorical_accuracy: 0.8402 - val_loss: 1.1772 - val_sparse_categorical_accuracy: 0.7227 - val_sparse_top_k_categorical_accuracy: 0.8543
# Epoch 15/500
# 49988/49988 - 5s - loss: 1.6906 - sparse_categorical_accuracy: 0.4806 - sparse_top_k_categorical_accuracy: 0.8419 - val_loss: 1.0897 - val_sparse_categorical_accuracy: 0.7106 - val_sparse_top_k_categorical_accuracy: 0.8965
# Epoch 16/500
# 49988/49988 - 5s - loss: 1.6681 - sparse_categorical_accuracy: 0.4830 - sparse_top_k_categorical_accuracy: 0.8441 - val_loss: 1.1877 - val_sparse_categorical_accuracy: 0.6847 - val_sparse_top_k_categorical_accuracy: 0.8267
# Epoch 17/500
# 49988/49988 - 5s - loss: 1.6595 - sparse_categorical_accuracy: 0.4858 - sparse_top_k_categorical_accuracy: 0.8463 - val_loss: 1.1189 - val_sparse_categorical_accuracy: 0.6726 - val_sparse_top_k_categorical_accuracy: 0.8626
# Epoch 18/500
# 49988/49988 - 5s - loss: 1.6418 - sparse_categorical_accuracy: 0.4917 - sparse_top_k_categorical_accuracy: 0.8481 - val_loss: 1.1008 - val_sparse_categorical_accuracy: 0.6895 - val_sparse_top_k_categorical_accuracy: 0.8682
# Epoch 19/500
# 49988/49988 - 5s - loss: 1.6480 - sparse_categorical_accuracy: 0.4921 - sparse_top_k_categorical_accuracy: 0.8465 - val_loss: 1.0574 - val_sparse_categorical_accuracy: 0.7301 - val_sparse_top_k_categorical_accuracy: 0.8803
# Epoch 20/500
# 49988/49988 - 5s - loss: 1.6384 - sparse_categorical_accuracy: 0.4937 - sparse_top_k_categorical_accuracy: 0.8486 - val_loss: 1.0407 - val_sparse_categorical_accuracy: 0.7370 - val_sparse_top_k_categorical_accuracy: 0.8901
# Epoch 21/500
# 49988/49988 - 5s - loss: 1.6397 - sparse_categorical_accuracy: 0.4910 - sparse_top_k_categorical_accuracy: 0.8501 - val_loss: 1.0276 - val_sparse_categorical_accuracy: 0.7333 - val_sparse_top_k_categorical_accuracy: 0.8999
# Epoch 22/500
# 49988/49988 - 5s - loss: 1.6303 - sparse_categorical_accuracy: 0.4935 - sparse_top_k_categorical_accuracy: 0.8497 - val_loss: 1.0578 - val_sparse_categorical_accuracy: 0.7160 - val_sparse_top_k_categorical_accuracy: 0.8809
# Epoch 23/500
# 49988/49988 - 5s - loss: 1.6274 - sparse_categorical_accuracy: 0.4936 - sparse_top_k_categorical_accuracy: 0.8488 - val_loss: 1.0942 - val_sparse_categorical_accuracy: 0.6795 - val_sparse_top_k_categorical_accuracy: 0.8733
# Epoch 24/500
# 49988/49988 - 5s - loss: 1.6226 - sparse_categorical_accuracy: 0.4949 - sparse_top_k_categorical_accuracy: 0.8492 - val_loss: 1.0129 - val_sparse_categorical_accuracy: 0.7487 - val_sparse_top_k_categorical_accuracy: 0.8959
# Epoch 25/500
# 49988/49988 - 5s - loss: 1.6194 - sparse_categorical_accuracy: 0.4976 - sparse_top_k_categorical_accuracy: 0.8504 - val_loss: 1.0532 - val_sparse_categorical_accuracy: 0.7055 - val_sparse_top_k_categorical_accuracy: 0.9042
# Epoch 26/500
# 49988/49988 - 5s - loss: 1.6361 - sparse_categorical_accuracy: 0.4954 - sparse_top_k_categorical_accuracy: 0.8472 - val_loss: 0.9727 - val_sparse_categorical_accuracy: 0.7627 - val_sparse_top_k_categorical_accuracy: 0.9102
# Epoch 27/500
# 49988/49988 - 5s - loss: 1.6239 - sparse_categorical_accuracy: 0.4936 - sparse_top_k_categorical_accuracy: 0.8494 - val_loss: 1.1200 - val_sparse_categorical_accuracy: 0.6683 - val_sparse_top_k_categorical_accuracy: 0.8653
# Epoch 28/500
# 49988/49988 - 5s - loss: 1.6136 - sparse_categorical_accuracy: 0.4974 - sparse_top_k_categorical_accuracy: 0.8511 - val_loss: 0.9729 - val_sparse_categorical_accuracy: 0.7628 - val_sparse_top_k_categorical_accuracy: 0.9065
# Epoch 29/500
# 49988/49988 - 5s - loss: 1.6105 - sparse_categorical_accuracy: 0.5000 - sparse_top_k_categorical_accuracy: 0.8525 - val_loss: 1.1328 - val_sparse_categorical_accuracy: 0.7025 - val_sparse_top_k_categorical_accuracy: 0.8539
# Epoch 30/500
# 49988/49988 - 5s - loss: 1.6180 - sparse_categorical_accuracy: 0.4955 - sparse_top_k_categorical_accuracy: 0.8502 - val_loss: 1.0523 - val_sparse_categorical_accuracy: 0.7287 - val_sparse_top_k_categorical_accuracy: 0.8974
# Epoch 31/500
# 49988/49988 - 5s - loss: 1.6429 - sparse_categorical_accuracy: 0.4916 - sparse_top_k_categorical_accuracy: 0.8488 - val_loss: 1.0716 - val_sparse_categorical_accuracy: 0.7170 - val_sparse_top_k_categorical_accuracy: 0.8926
# Epoch 32/500
# 49988/49988 - 5s - loss: 1.6221 - sparse_categorical_accuracy: 0.4902 - sparse_top_k_categorical_accuracy: 0.8477 - val_loss: 1.1053 - val_sparse_categorical_accuracy: 0.6929 - val_sparse_top_k_categorical_accuracy: 0.8678
# Epoch 33/500
# 49988/49988 - 5s - loss: 1.6083 - sparse_categorical_accuracy: 0.4961 - sparse_top_k_categorical_accuracy: 0.8495 - val_loss: 1.0566 - val_sparse_categorical_accuracy: 0.7311 - val_sparse_top_k_categorical_accuracy: 0.8744
# Epoch 34/500
# 49988/49988 - 5s - loss: 1.6071 - sparse_categorical_accuracy: 0.4952 - sparse_top_k_categorical_accuracy: 0.8514 - val_loss: 1.0524 - val_sparse_categorical_accuracy: 0.6814 - val_sparse_top_k_categorical_accuracy: 0.8790
# Epoch 35/500
# 49988/49988 - 5s - loss: 1.5946 - sparse_categorical_accuracy: 0.4991 - sparse_top_k_categorical_accuracy: 0.8533 - val_loss: 1.0638 - val_sparse_categorical_accuracy: 0.7293 - val_sparse_top_k_categorical_accuracy: 0.8719
# Epoch 36/500
# Restoring model weights from the end of the best epoch.
# 49988/49988 - 5s - loss: 1.5910 - sparse_categorical_accuracy: 0.5014 - sparse_top_k_categorical_accuracy: 0.8530 - val_loss: 1.0139 - val_sparse_categorical_accuracy: 0.7370 - val_sparse_top_k_categorical_accuracy: 0.8876
# Epoch 00036: early stopping
# FITTING NN ON BOOTSTRAP 1
#
#
# Train on 49988 samples, validate on 53363 samples
# Epoch 1/500
# 49988/49988 - 6s - loss: 3.3706 - sparse_categorical_accuracy: 0.4005 - sparse_top_k_categorical_accuracy: 0.7703 - val_loss: 1.4729 - val_sparse_categorical_accuracy: 0.6625 - val_sparse_top_k_categorical_accuracy: 0.8116
# Epoch 2/500
# 49988/49988 - 5s - loss: 1.8301 - sparse_categorical_accuracy: 0.4589 - sparse_top_k_categorical_accuracy: 0.8243 - val_loss: 1.2497 - val_sparse_categorical_accuracy: 0.6772 - val_sparse_top_k_categorical_accuracy: 0.8179
# Epoch 3/500
# 49988/49988 - 5s - loss: 1.7623 - sparse_categorical_accuracy: 0.4642 - sparse_top_k_categorical_accuracy: 0.8293 - val_loss: 1.2539 - val_sparse_categorical_accuracy: 0.6469 - val_sparse_top_k_categorical_accuracy: 0.8367
# Epoch 4/500
# 49988/49988 - 5s - loss: 1.7419 - sparse_categorical_accuracy: 0.4655 - sparse_top_k_categorical_accuracy: 0.8350 - val_loss: 1.3578 - val_sparse_categorical_accuracy: 0.6287 - val_sparse_top_k_categorical_accuracy: 0.7828
# Epoch 5/500
# 49988/49988 - 5s - loss: 1.7373 - sparse_categorical_accuracy: 0.4707 - sparse_top_k_categorical_accuracy: 0.8343 - val_loss: 1.2969 - val_sparse_categorical_accuracy: 0.6392 - val_sparse_top_k_categorical_accuracy: 0.7896
# Epoch 6/500
# 49988/49988 - 5s - loss: 1.7117 - sparse_categorical_accuracy: 0.4731 - sparse_top_k_categorical_accuracy: 0.8372 - val_loss: 1.4460 - val_sparse_categorical_accuracy: 0.6422 - val_sparse_top_k_categorical_accuracy: 0.8707
# Epoch 7/500
# 49988/49988 - 5s - loss: 1.7396 - sparse_categorical_accuracy: 0.4716 - sparse_top_k_categorical_accuracy: 0.8349 - val_loss: 1.2280 - val_sparse_categorical_accuracy: 0.6598 - val_sparse_top_k_categorical_accuracy: 0.8441
# Epoch 8/500
# 49988/49988 - 5s - loss: 1.6958 - sparse_categorical_accuracy: 0.4758 - sparse_top_k_categorical_accuracy: 0.8393 - val_loss: 1.1507 - val_sparse_categorical_accuracy: 0.6982 - val_sparse_top_k_categorical_accuracy: 0.8679
# Epoch 9/500
# 49988/49988 - 5s - loss: 1.6824 - sparse_categorical_accuracy: 0.4798 - sparse_top_k_categorical_accuracy: 0.8406 - val_loss: 1.1287 - val_sparse_categorical_accuracy: 0.7237 - val_sparse_top_k_categorical_accuracy: 0.8591
# Epoch 10/500
# 49988/49988 - 5s - loss: 1.6755 - sparse_categorical_accuracy: 0.4821 - sparse_top_k_categorical_accuracy: 0.8426 - val_loss: 1.1176 - val_sparse_categorical_accuracy: 0.6853 - val_sparse_top_k_categorical_accuracy: 0.8709
# Epoch 11/500
# 49988/49988 - 5s - loss: 1.6842 - sparse_categorical_accuracy: 0.4835 - sparse_top_k_categorical_accuracy: 0.8390 - val_loss: 1.1566 - val_sparse_categorical_accuracy: 0.6817 - val_sparse_top_k_categorical_accuracy: 0.8468
# Epoch 12/500
# 49988/49988 - 5s - loss: 1.6731 - sparse_categorical_accuracy: 0.4845 - sparse_top_k_categorical_accuracy: 0.8429 - val_loss: 1.2374 - val_sparse_categorical_accuracy: 0.6400 - val_sparse_top_k_categorical_accuracy: 0.8247
# Epoch 13/500
# 49988/49988 - 5s - loss: 1.7084 - sparse_categorical_accuracy: 0.4779 - sparse_top_k_categorical_accuracy: 0.8420 - val_loss: 1.2239 - val_sparse_categorical_accuracy: 0.6369 - val_sparse_top_k_categorical_accuracy: 0.8302
# Epoch 14/500
# 49988/49988 - 5s - loss: 1.6894 - sparse_categorical_accuracy: 0.4828 - sparse_top_k_categorical_accuracy: 0.8435 - val_loss: 1.2411 - val_sparse_categorical_accuracy: 0.6446 - val_sparse_top_k_categorical_accuracy: 0.8542
# Epoch 15/500
# 49988/49988 - 5s - loss: 1.6710 - sparse_categorical_accuracy: 0.4877 - sparse_top_k_categorical_accuracy: 0.8430 - val_loss: 1.1942 - val_sparse_categorical_accuracy: 0.6796 - val_sparse_top_k_categorical_accuracy: 0.8330
# Epoch 16/500
# 49988/49988 - 5s - loss: 1.6340 - sparse_categorical_accuracy: 0.4951 - sparse_top_k_categorical_accuracy: 0.8489 - val_loss: 1.0964 - val_sparse_categorical_accuracy: 0.6988 - val_sparse_top_k_categorical_accuracy: 0.8723
# Epoch 17/500
# 49988/49988 - 5s - loss: 1.6426 - sparse_categorical_accuracy: 0.4904 - sparse_top_k_categorical_accuracy: 0.8456 - val_loss: 1.2926 - val_sparse_categorical_accuracy: 0.6555 - val_sparse_top_k_categorical_accuracy: 0.8653
# Epoch 18/500
# 49988/49988 - 5s - loss: 1.6343 - sparse_categorical_accuracy: 0.4952 - sparse_top_k_categorical_accuracy: 0.8478 - val_loss: 1.0479 - val_sparse_categorical_accuracy: 0.7127 - val_sparse_top_k_categorical_accuracy: 0.8938
# Epoch 19/500
# 49988/49988 - 5s - loss: 1.6363 - sparse_categorical_accuracy: 0.4925 - sparse_top_k_categorical_accuracy: 0.8463 - val_loss: 1.0492 - val_sparse_categorical_accuracy: 0.7361 - val_sparse_top_k_categorical_accuracy: 0.8826
# Epoch 20/500
# 49988/49988 - 6s - loss: 1.6458 - sparse_categorical_accuracy: 0.4914 - sparse_top_k_categorical_accuracy: 0.8486 - val_loss: 1.2814 - val_sparse_categorical_accuracy: 0.6832 - val_sparse_top_k_categorical_accuracy: 0.8905
# Epoch 21/500
# 49988/49988 - 6s - loss: 1.6715 - sparse_categorical_accuracy: 0.4870 - sparse_top_k_categorical_accuracy: 0.8442 - val_loss: 1.1525 - val_sparse_categorical_accuracy: 0.6646 - val_sparse_top_k_categorical_accuracy: 0.9057
# Epoch 22/500
# 49988/49988 - 5s - loss: 1.6951 - sparse_categorical_accuracy: 0.4832 - sparse_top_k_categorical_accuracy: 0.8427 - val_loss: 1.1348 - val_sparse_categorical_accuracy: 0.6764 - val_sparse_top_k_categorical_accuracy: 0.8608
# Epoch 23/500
# 49988/49988 - 5s - loss: 1.6539 - sparse_categorical_accuracy: 0.4882 - sparse_top_k_categorical_accuracy: 0.8442 - val_loss: 1.0333 - val_sparse_categorical_accuracy: 0.7082 - val_sparse_top_k_categorical_accuracy: 0.8954
# Epoch 24/500
# 49988/49988 - 5s - loss: 1.6295 - sparse_categorical_accuracy: 0.4950 - sparse_top_k_categorical_accuracy: 0.8488 - val_loss: 1.1034 - val_sparse_categorical_accuracy: 0.7225 - val_sparse_top_k_categorical_accuracy: 0.8685
# Epoch 25/500
# 49988/49988 - 5s - loss: 1.6396 - sparse_categorical_accuracy: 0.4917 - sparse_top_k_categorical_accuracy: 0.8488 - val_loss: 1.0798 - val_sparse_categorical_accuracy: 0.7031 - val_sparse_top_k_categorical_accuracy: 0.8744
# Epoch 26/500
# 49988/49988 - 5s - loss: 1.6129 - sparse_categorical_accuracy: 0.4983 - sparse_top_k_categorical_accuracy: 0.8479 - val_loss: 0.9838 - val_sparse_categorical_accuracy: 0.7516 - val_sparse_top_k_categorical_accuracy: 0.8962
# Epoch 27/500
# 49988/49988 - 5s - loss: 1.6065 - sparse_categorical_accuracy: 0.4998 - sparse_top_k_categorical_accuracy: 0.8519 - val_loss: 1.0641 - val_sparse_categorical_accuracy: 0.7415 - val_sparse_top_k_categorical_accuracy: 0.8720
# Epoch 28/500
# 49988/49988 - 5s - loss: 1.6050 - sparse_categorical_accuracy: 0.4958 - sparse_top_k_categorical_accuracy: 0.8513 - val_loss: 1.1197 - val_sparse_categorical_accuracy: 0.6656 - val_sparse_top_k_categorical_accuracy: 0.8750
# Epoch 29/500
# 49988/49988 - 5s - loss: 1.6171 - sparse_categorical_accuracy: 0.4935 - sparse_top_k_categorical_accuracy: 0.8486 - val_loss: 1.0649 - val_sparse_categorical_accuracy: 0.6980 - val_sparse_top_k_categorical_accuracy: 0.8903
# Epoch 30/500
# 49988/49988 - 5s - loss: 1.6160 - sparse_categorical_accuracy: 0.4951 - sparse_top_k_categorical_accuracy: 0.8481 - val_loss: 1.0789 - val_sparse_categorical_accuracy: 0.7013 - val_sparse_top_k_categorical_accuracy: 0.8677
# Epoch 31/500
# 49988/49988 - 5s - loss: 1.6021 - sparse_categorical_accuracy: 0.4988 - sparse_top_k_categorical_accuracy: 0.8507 - val_loss: 1.0036 - val_sparse_categorical_accuracy: 0.7498 - val_sparse_top_k_categorical_accuracy: 0.8876
# Epoch 32/500
# 49988/49988 - 5s - loss: 1.6001 - sparse_categorical_accuracy: 0.5003 - sparse_top_k_categorical_accuracy: 0.8508 - val_loss: 1.1319 - val_sparse_categorical_accuracy: 0.7021 - val_sparse_top_k_categorical_accuracy: 0.8603
# Epoch 33/500
# 49988/49988 - 5s - loss: 1.6357 - sparse_categorical_accuracy: 0.4913 - sparse_top_k_categorical_accuracy: 0.8475 - val_loss: 1.0850 - val_sparse_categorical_accuracy: 0.7065 - val_sparse_top_k_categorical_accuracy: 0.8794
# Epoch 34/500
# 49988/49988 - 5s - loss: 1.6427 - sparse_categorical_accuracy: 0.4860 - sparse_top_k_categorical_accuracy: 0.8450 - val_loss: 1.1347 - val_sparse_categorical_accuracy: 0.6812 - val_sparse_top_k_categorical_accuracy: 0.8404
# Epoch 35/500
# 49988/49988 - 5s - loss: 1.6013 - sparse_categorical_accuracy: 0.4981 - sparse_top_k_categorical_accuracy: 0.8488 - val_loss: 0.9824 - val_sparse_categorical_accuracy: 0.7424 - val_sparse_top_k_categorical_accuracy: 0.9003
# Epoch 36/500
# 49988/49988 - 5s - loss: 1.5955 - sparse_categorical_accuracy: 0.4983 - sparse_top_k_categorical_accuracy: 0.8518 - val_loss: 0.9309 - val_sparse_categorical_accuracy: 0.7628 - val_sparse_top_k_categorical_accuracy: 0.9180
# Epoch 37/500
# 49988/49988 - 5s - loss: 1.5885 - sparse_categorical_accuracy: 0.5015 - sparse_top_k_categorical_accuracy: 0.8523 - val_loss: 0.9840 - val_sparse_categorical_accuracy: 0.7078 - val_sparse_top_k_categorical_accuracy: 0.9094
# Epoch 38/500
# 49988/49988 - 5s - loss: 1.5871 - sparse_categorical_accuracy: 0.5031 - sparse_top_k_categorical_accuracy: 0.8522 - val_loss: 1.1274 - val_sparse_categorical_accuracy: 0.6880 - val_sparse_top_k_categorical_accuracy: 0.8423
# Epoch 39/500
# 49988/49988 - 5s - loss: 1.6081 - sparse_categorical_accuracy: 0.4992 - sparse_top_k_categorical_accuracy: 0.8486 - val_loss: 1.0054 - val_sparse_categorical_accuracy: 0.7583 - val_sparse_top_k_categorical_accuracy: 0.8988
# Epoch 40/500
# 49988/49988 - 5s - loss: 1.5950 - sparse_categorical_accuracy: 0.5019 - sparse_top_k_categorical_accuracy: 0.8528 - val_loss: 1.0096 - val_sparse_categorical_accuracy: 0.7624 - val_sparse_top_k_categorical_accuracy: 0.8979
# Epoch 41/500
# 49988/49988 - 5s - loss: 1.5971 - sparse_categorical_accuracy: 0.5002 - sparse_top_k_categorical_accuracy: 0.8525 - val_loss: 1.0020 - val_sparse_categorical_accuracy: 0.7476 - val_sparse_top_k_categorical_accuracy: 0.8953
# Epoch 42/500
# 49988/49988 - 5s - loss: 1.5893 - sparse_categorical_accuracy: 0.4999 - sparse_top_k_categorical_accuracy: 0.8511 - val_loss: 1.0866 - val_sparse_categorical_accuracy: 0.7252 - val_sparse_top_k_categorical_accuracy: 0.8670
# Epoch 43/500
# 49988/49988 - 5s - loss: 1.5820 - sparse_categorical_accuracy: 0.5034 - sparse_top_k_categorical_accuracy: 0.8557 - val_loss: 0.9209 - val_sparse_categorical_accuracy: 0.7689 - val_sparse_top_k_categorical_accuracy: 0.9267
# Epoch 44/500
# 49988/49988 - 5s - loss: 1.5755 - sparse_categorical_accuracy: 0.5056 - sparse_top_k_categorical_accuracy: 0.8547 - val_loss: 0.9973 - val_sparse_categorical_accuracy: 0.7484 - val_sparse_top_k_categorical_accuracy: 0.8988
# Epoch 45/500
# 49988/49988 - 5s - loss: 1.5803 - sparse_categorical_accuracy: 0.5041 - sparse_top_k_categorical_accuracy: 0.8562 - val_loss: 1.0415 - val_sparse_categorical_accuracy: 0.7523 - val_sparse_top_k_categorical_accuracy: 0.8931
# Epoch 46/500
# 49988/49988 - 5s - loss: 1.5796 - sparse_categorical_accuracy: 0.5028 - sparse_top_k_categorical_accuracy: 0.8546 - val_loss: 1.0929 - val_sparse_categorical_accuracy: 0.7291 - val_sparse_top_k_categorical_accuracy: 0.8616
# Epoch 47/500
# 49988/49988 - 5s - loss: 1.5820 - sparse_categorical_accuracy: 0.5048 - sparse_top_k_categorical_accuracy: 0.8519 - val_loss: 1.1048 - val_sparse_categorical_accuracy: 0.6519 - val_sparse_top_k_categorical_accuracy: 0.8672
# Epoch 48/500
# 49988/49988 - 5s - loss: 1.6041 - sparse_categorical_accuracy: 0.5001 - sparse_top_k_categorical_accuracy: 0.8512 - val_loss: 0.9587 - val_sparse_categorical_accuracy: 0.7624 - val_sparse_top_k_categorical_accuracy: 0.9133
# Epoch 49/500
# 49988/49988 - 5s - loss: 1.5967 - sparse_categorical_accuracy: 0.4975 - sparse_top_k_categorical_accuracy: 0.8528 - val_loss: 1.0906 - val_sparse_categorical_accuracy: 0.6823 - val_sparse_top_k_categorical_accuracy: 0.8665
# Epoch 50/500
# 49988/49988 - 5s - loss: 1.6021 - sparse_categorical_accuracy: 0.4989 - sparse_top_k_categorical_accuracy: 0.8514 - val_loss: 0.9281 - val_sparse_categorical_accuracy: 0.7576 - val_sparse_top_k_categorical_accuracy: 0.9186
# Epoch 51/500
# 49988/49988 - 5s - loss: 1.5848 - sparse_categorical_accuracy: 0.5042 - sparse_top_k_categorical_accuracy: 0.8517 - val_loss: 1.0375 - val_sparse_categorical_accuracy: 0.7027 - val_sparse_top_k_categorical_accuracy: 0.8886
# Epoch 52/500
# 49988/49988 - 5s - loss: 1.5824 - sparse_categorical_accuracy: 0.5025 - sparse_top_k_categorical_accuracy: 0.8549 - val_loss: 1.0517 - val_sparse_categorical_accuracy: 0.7477 - val_sparse_top_k_categorical_accuracy: 0.8683
# Epoch 53/500
# Restoring model weights from the end of the best epoch.
# 49988/49988 - 5s - loss: 1.6127 - sparse_categorical_accuracy: 0.4997 - sparse_top_k_categorical_accuracy: 0.8497 - val_loss: 1.0462 - val_sparse_categorical_accuracy: 0.7166 - val_sparse_top_k_categorical_accuracy: 0.8863
# Epoch 00053: early stopping
# FITTING NN ON BOOTSTRAP 2
#
#
# Train on 49988 samples, validate on 53363 samples
# Epoch 1/500
# 49988/49988 - 6s - loss: 3.3742 - sparse_categorical_accuracy: 0.4028 - sparse_top_k_categorical_accuracy: 0.7729 - val_loss: 1.4670 - val_sparse_categorical_accuracy: 0.6081 - val_sparse_top_k_categorical_accuracy: 0.8062
# Epoch 2/500
# 49988/49988 - 6s - loss: 1.8464 - sparse_categorical_accuracy: 0.4551 - sparse_top_k_categorical_accuracy: 0.8266 - val_loss: 1.3226 - val_sparse_categorical_accuracy: 0.6679 - val_sparse_top_k_categorical_accuracy: 0.8123
# Epoch 3/500
# 49988/49988 - 5s - loss: 1.7591 - sparse_categorical_accuracy: 0.4661 - sparse_top_k_categorical_accuracy: 0.8343 - val_loss: 1.3748 - val_sparse_categorical_accuracy: 0.6237 - val_sparse_top_k_categorical_accuracy: 0.7930
# Epoch 4/500
# 49988/49988 - 5s - loss: 1.7472 - sparse_categorical_accuracy: 0.4711 - sparse_top_k_categorical_accuracy: 0.8341 - val_loss: 1.2332 - val_sparse_categorical_accuracy: 0.6547 - val_sparse_top_k_categorical_accuracy: 0.8386
# Epoch 5/500
# 49988/49988 - 5s - loss: 1.7427 - sparse_categorical_accuracy: 0.4726 - sparse_top_k_categorical_accuracy: 0.8367 - val_loss: 1.2965 - val_sparse_categorical_accuracy: 0.7005 - val_sparse_top_k_categorical_accuracy: 0.8191
# Epoch 6/500
# 49988/49988 - 5s - loss: 1.7139 - sparse_categorical_accuracy: 0.4723 - sparse_top_k_categorical_accuracy: 0.8393 - val_loss: 1.2172 - val_sparse_categorical_accuracy: 0.6794 - val_sparse_top_k_categorical_accuracy: 0.8188
# Epoch 7/500
# 49988/49988 - 5s - loss: 1.6976 - sparse_categorical_accuracy: 0.4770 - sparse_top_k_categorical_accuracy: 0.8411 - val_loss: 1.1793 - val_sparse_categorical_accuracy: 0.6722 - val_sparse_top_k_categorical_accuracy: 0.8420
# Epoch 8/500
# 49988/49988 - 5s - loss: 1.6863 - sparse_categorical_accuracy: 0.4821 - sparse_top_k_categorical_accuracy: 0.8401 - val_loss: 1.1723 - val_sparse_categorical_accuracy: 0.6817 - val_sparse_top_k_categorical_accuracy: 0.8372
# Epoch 9/500
# 49988/49988 - 5s - loss: 1.6886 - sparse_categorical_accuracy: 0.4809 - sparse_top_k_categorical_accuracy: 0.8428 - val_loss: 1.2458 - val_sparse_categorical_accuracy: 0.6586 - val_sparse_top_k_categorical_accuracy: 0.8262
# Epoch 10/500
# 49988/49988 - 5s - loss: 1.7563 - sparse_categorical_accuracy: 0.4727 - sparse_top_k_categorical_accuracy: 0.8351 - val_loss: 1.2723 - val_sparse_categorical_accuracy: 0.6394 - val_sparse_top_k_categorical_accuracy: 0.8376
# Epoch 11/500
# 49988/49988 - 5s - loss: 1.6955 - sparse_categorical_accuracy: 0.4774 - sparse_top_k_categorical_accuracy: 0.8422 - val_loss: 1.0920 - val_sparse_categorical_accuracy: 0.7272 - val_sparse_top_k_categorical_accuracy: 0.8717
# Epoch 12/500
# 49988/49988 - 5s - loss: 1.6822 - sparse_categorical_accuracy: 0.4835 - sparse_top_k_categorical_accuracy: 0.8444 - val_loss: 1.2013 - val_sparse_categorical_accuracy: 0.7028 - val_sparse_top_k_categorical_accuracy: 0.8375
# Epoch 13/500
# 49988/49988 - 5s - loss: 1.6744 - sparse_categorical_accuracy: 0.4841 - sparse_top_k_categorical_accuracy: 0.8452 - val_loss: 1.1098 - val_sparse_categorical_accuracy: 0.7201 - val_sparse_top_k_categorical_accuracy: 0.8687
# Epoch 14/500
# 49988/49988 - 5s - loss: 1.6866 - sparse_categorical_accuracy: 0.4841 - sparse_top_k_categorical_accuracy: 0.8443 - val_loss: 1.1220 - val_sparse_categorical_accuracy: 0.6861 - val_sparse_top_k_categorical_accuracy: 0.8624
# Epoch 15/500
# 49988/49988 - 5s - loss: 1.6722 - sparse_categorical_accuracy: 0.4909 - sparse_top_k_categorical_accuracy: 0.8467 - val_loss: 1.1928 - val_sparse_categorical_accuracy: 0.6654 - val_sparse_top_k_categorical_accuracy: 0.8423
# Epoch 16/500
# 49988/49988 - 5s - loss: 1.6617 - sparse_categorical_accuracy: 0.4865 - sparse_top_k_categorical_accuracy: 0.8470 - val_loss: 1.0566 - val_sparse_categorical_accuracy: 0.7360 - val_sparse_top_k_categorical_accuracy: 0.8838
# Epoch 17/500
# 49988/49988 - 5s - loss: 1.6514 - sparse_categorical_accuracy: 0.4916 - sparse_top_k_categorical_accuracy: 0.8446 - val_loss: 1.1205 - val_sparse_categorical_accuracy: 0.7355 - val_sparse_top_k_categorical_accuracy: 0.8604
# Epoch 18/500
# 49988/49988 - 5s - loss: 1.6618 - sparse_categorical_accuracy: 0.4904 - sparse_top_k_categorical_accuracy: 0.8439 - val_loss: 1.0846 - val_sparse_categorical_accuracy: 0.6981 - val_sparse_top_k_categorical_accuracy: 0.8623
# Epoch 19/500
# 49988/49988 - 5s - loss: 1.6441 - sparse_categorical_accuracy: 0.4933 - sparse_top_k_categorical_accuracy: 0.8465 - val_loss: 1.0904 - val_sparse_categorical_accuracy: 0.7283 - val_sparse_top_k_categorical_accuracy: 0.8883
# Epoch 20/500
# 49988/49988 - 5s - loss: 1.6365 - sparse_categorical_accuracy: 0.4957 - sparse_top_k_categorical_accuracy: 0.8485 - val_loss: 1.1456 - val_sparse_categorical_accuracy: 0.7278 - val_sparse_top_k_categorical_accuracy: 0.8545
# Epoch 21/500
# 49988/49988 - 5s - loss: 1.6752 - sparse_categorical_accuracy: 0.4869 - sparse_top_k_categorical_accuracy: 0.8451 - val_loss: 1.1615 - val_sparse_categorical_accuracy: 0.6817 - val_sparse_top_k_categorical_accuracy: 0.8465
# Epoch 22/500
# 49988/49988 - 5s - loss: 1.7254 - sparse_categorical_accuracy: 0.4837 - sparse_top_k_categorical_accuracy: 0.8395 - val_loss: 1.1422 - val_sparse_categorical_accuracy: 0.7460 - val_sparse_top_k_categorical_accuracy: 0.8498
# Epoch 23/500
# 49988/49988 - 5s - loss: 1.6589 - sparse_categorical_accuracy: 0.4897 - sparse_top_k_categorical_accuracy: 0.8455 - val_loss: 1.2188 - val_sparse_categorical_accuracy: 0.6420 - val_sparse_top_k_categorical_accuracy: 0.8240
# Epoch 24/500
# 49988/49988 - 5s - loss: 1.6509 - sparse_categorical_accuracy: 0.4926 - sparse_top_k_categorical_accuracy: 0.8460 - val_loss: 1.1042 - val_sparse_categorical_accuracy: 0.6947 - val_sparse_top_k_categorical_accuracy: 0.8664
# Epoch 25/500
# 49988/49988 - 5s - loss: 1.6434 - sparse_categorical_accuracy: 0.4936 - sparse_top_k_categorical_accuracy: 0.8477 - val_loss: 1.2046 - val_sparse_categorical_accuracy: 0.6921 - val_sparse_top_k_categorical_accuracy: 0.8616
# Epoch 26/500
# Restoring model weights from the end of the best epoch.
# 49988/49988 - 6s - loss: 1.6324 - sparse_categorical_accuracy: 0.4947 - sparse_top_k_categorical_accuracy: 0.8490 - val_loss: 1.1563 - val_sparse_categorical_accuracy: 0.6720 - val_sparse_top_k_categorical_accuracy: 0.8542
# Epoch 00026: early stopping
# FITTING NN ON BOOTSTRAP 3
#
#
# Train on 49988 samples, validate on 53363 samples
# Epoch 1/500
# 49988/49988 - 6s - loss: 3.3266 - sparse_categorical_accuracy: 0.3963 - sparse_top_k_categorical_accuracy: 0.7668 - val_loss: 1.3464 - val_sparse_categorical_accuracy: 0.6366 - val_sparse_top_k_categorical_accuracy: 0.8556
# Epoch 2/500
# 49988/49988 - 5s - loss: 1.8301 - sparse_categorical_accuracy: 0.4572 - sparse_top_k_categorical_accuracy: 0.8295 - val_loss: 1.3020 - val_sparse_categorical_accuracy: 0.6477 - val_sparse_top_k_categorical_accuracy: 0.8185
# Epoch 3/500
# 49988/49988 - 5s - loss: 1.7612 - sparse_categorical_accuracy: 0.4661 - sparse_top_k_categorical_accuracy: 0.8352 - val_loss: 1.6615 - val_sparse_categorical_accuracy: 0.5941 - val_sparse_top_k_categorical_accuracy: 0.7696
# Epoch 4/500
# 49988/49988 - 5s - loss: 1.7547 - sparse_categorical_accuracy: 0.4694 - sparse_top_k_categorical_accuracy: 0.8374 - val_loss: 1.2238 - val_sparse_categorical_accuracy: 0.6686 - val_sparse_top_k_categorical_accuracy: 0.8263
# Epoch 5/500
# 49988/49988 - 5s - loss: 1.7228 - sparse_categorical_accuracy: 0.4711 - sparse_top_k_categorical_accuracy: 0.8397 - val_loss: 1.2750 - val_sparse_categorical_accuracy: 0.6333 - val_sparse_top_k_categorical_accuracy: 0.8401
# Epoch 6/500
# 49988/49988 - 5s - loss: 1.7121 - sparse_categorical_accuracy: 0.4753 - sparse_top_k_categorical_accuracy: 0.8430 - val_loss: 1.2352 - val_sparse_categorical_accuracy: 0.6962 - val_sparse_top_k_categorical_accuracy: 0.8493
# Epoch 7/500
# 49988/49988 - 5s - loss: 1.7135 - sparse_categorical_accuracy: 0.4781 - sparse_top_k_categorical_accuracy: 0.8424 - val_loss: 1.2125 - val_sparse_categorical_accuracy: 0.6576 - val_sparse_top_k_categorical_accuracy: 0.8474
# Epoch 8/500
# 49988/49988 - 5s - loss: 1.6939 - sparse_categorical_accuracy: 0.4825 - sparse_top_k_categorical_accuracy: 0.8436 - val_loss: 1.1169 - val_sparse_categorical_accuracy: 0.7097 - val_sparse_top_k_categorical_accuracy: 0.8773
# Epoch 9/500
# 49988/49988 - 5s - loss: 1.6879 - sparse_categorical_accuracy: 0.4839 - sparse_top_k_categorical_accuracy: 0.8455 - val_loss: 1.2973 - val_sparse_categorical_accuracy: 0.6495 - val_sparse_top_k_categorical_accuracy: 0.8657
# Epoch 10/500
# 49988/49988 - 5s - loss: 1.7103 - sparse_categorical_accuracy: 0.4825 - sparse_top_k_categorical_accuracy: 0.8446 - val_loss: 1.2296 - val_sparse_categorical_accuracy: 0.6518 - val_sparse_top_k_categorical_accuracy: 0.8275
# Epoch 11/500
# 49988/49988 - 5s - loss: 1.6782 - sparse_categorical_accuracy: 0.4864 - sparse_top_k_categorical_accuracy: 0.8448 - val_loss: 1.1611 - val_sparse_categorical_accuracy: 0.7061 - val_sparse_top_k_categorical_accuracy: 0.8531
# Epoch 12/500
# 49988/49988 - 5s - loss: 1.6709 - sparse_categorical_accuracy: 0.4894 - sparse_top_k_categorical_accuracy: 0.8475 - val_loss: 1.1021 - val_sparse_categorical_accuracy: 0.6954 - val_sparse_top_k_categorical_accuracy: 0.8769
# Epoch 13/500
# 49988/49988 - 5s - loss: 1.6925 - sparse_categorical_accuracy: 0.4824 - sparse_top_k_categorical_accuracy: 0.8478 - val_loss: 1.2384 - val_sparse_categorical_accuracy: 0.7081 - val_sparse_top_k_categorical_accuracy: 0.8517
# Epoch 14/500
# 49988/49988 - 5s - loss: 1.6603 - sparse_categorical_accuracy: 0.4906 - sparse_top_k_categorical_accuracy: 0.8529 - val_loss: 1.1741 - val_sparse_categorical_accuracy: 0.6516 - val_sparse_top_k_categorical_accuracy: 0.8554
# Epoch 15/500
# 49988/49988 - 5s - loss: 1.6530 - sparse_categorical_accuracy: 0.4967 - sparse_top_k_categorical_accuracy: 0.8508 - val_loss: 1.2264 - val_sparse_categorical_accuracy: 0.6716 - val_sparse_top_k_categorical_accuracy: 0.8703
# Epoch 16/500
# 49988/49988 - 5s - loss: 1.6883 - sparse_categorical_accuracy: 0.4881 - sparse_top_k_categorical_accuracy: 0.8474 - val_loss: 1.0417 - val_sparse_categorical_accuracy: 0.7563 - val_sparse_top_k_categorical_accuracy: 0.8998
# Epoch 17/500
# 49988/49988 - 5s - loss: 1.6342 - sparse_categorical_accuracy: 0.4995 - sparse_top_k_categorical_accuracy: 0.8521 - val_loss: 1.1516 - val_sparse_categorical_accuracy: 0.6966 - val_sparse_top_k_categorical_accuracy: 0.8560
# Epoch 18/500
# 49988/49988 - 5s - loss: 1.6408 - sparse_categorical_accuracy: 0.4979 - sparse_top_k_categorical_accuracy: 0.8499 - val_loss: 1.0147 - val_sparse_categorical_accuracy: 0.7485 - val_sparse_top_k_categorical_accuracy: 0.9042
# Epoch 19/500
# 49988/49988 - 5s - loss: 1.6271 - sparse_categorical_accuracy: 0.5008 - sparse_top_k_categorical_accuracy: 0.8531 - val_loss: 1.0629 - val_sparse_categorical_accuracy: 0.6984 - val_sparse_top_k_categorical_accuracy: 0.8961
# Epoch 20/500
# 49988/49988 - 5s - loss: 1.6307 - sparse_categorical_accuracy: 0.5023 - sparse_top_k_categorical_accuracy: 0.8528 - val_loss: 1.2443 - val_sparse_categorical_accuracy: 0.6880 - val_sparse_top_k_categorical_accuracy: 0.8724
# Epoch 21/500
# 49988/49988 - 5s - loss: 1.6126 - sparse_categorical_accuracy: 0.5054 - sparse_top_k_categorical_accuracy: 0.8530 - val_loss: 1.1391 - val_sparse_categorical_accuracy: 0.6753 - val_sparse_top_k_categorical_accuracy: 0.8790
# Epoch 22/500
# 49988/49988 - 5s - loss: 1.6460 - sparse_categorical_accuracy: 0.4973 - sparse_top_k_categorical_accuracy: 0.8513 - val_loss: 1.0601 - val_sparse_categorical_accuracy: 0.7555 - val_sparse_top_k_categorical_accuracy: 0.8812
# Epoch 23/500
# 49988/49988 - 5s - loss: 1.6413 - sparse_categorical_accuracy: 0.4982 - sparse_top_k_categorical_accuracy: 0.8512 - val_loss: 1.0882 - val_sparse_categorical_accuracy: 0.7211 - val_sparse_top_k_categorical_accuracy: 0.8890
# Epoch 24/500
# 49988/49988 - 5s - loss: 1.6133 - sparse_categorical_accuracy: 0.5023 - sparse_top_k_categorical_accuracy: 0.8517 - val_loss: 1.0546 - val_sparse_categorical_accuracy: 0.7304 - val_sparse_top_k_categorical_accuracy: 0.8789
# Epoch 25/500
# 49988/49988 - 5s - loss: 1.5992 - sparse_categorical_accuracy: 0.5076 - sparse_top_k_categorical_accuracy: 0.8536 - val_loss: 1.0744 - val_sparse_categorical_accuracy: 0.7201 - val_sparse_top_k_categorical_accuracy: 0.8830
# Epoch 26/500
# 49988/49988 - 5s - loss: 1.5919 - sparse_categorical_accuracy: 0.5076 - sparse_top_k_categorical_accuracy: 0.8534 - val_loss: 1.1263 - val_sparse_categorical_accuracy: 0.7106 - val_sparse_top_k_categorical_accuracy: 0.8922
# Epoch 27/500
# 49988/49988 - 5s - loss: 1.5896 - sparse_categorical_accuracy: 0.5085 - sparse_top_k_categorical_accuracy: 0.8565 - val_loss: 1.0904 - val_sparse_categorical_accuracy: 0.7066 - val_sparse_top_k_categorical_accuracy: 0.8884
# Epoch 28/500
# 49988/49988 - 5s - loss: 1.5899 - sparse_categorical_accuracy: 0.5067 - sparse_top_k_categorical_accuracy: 0.8547 - val_loss: 0.9916 - val_sparse_categorical_accuracy: 0.7349 - val_sparse_top_k_categorical_accuracy: 0.9061
# Epoch 29/500
# 49988/49988 - 5s - loss: 1.5883 - sparse_categorical_accuracy: 0.5042 - sparse_top_k_categorical_accuracy: 0.8566 - val_loss: 1.0089 - val_sparse_categorical_accuracy: 0.7398 - val_sparse_top_k_categorical_accuracy: 0.8911
# Epoch 30/500
# 49988/49988 - 5s - loss: 1.5889 - sparse_categorical_accuracy: 0.5119 - sparse_top_k_categorical_accuracy: 0.8555 - val_loss: 1.0929 - val_sparse_categorical_accuracy: 0.6754 - val_sparse_top_k_categorical_accuracy: 0.8809
# Epoch 31/500
# 49988/49988 - 5s - loss: 1.5998 - sparse_categorical_accuracy: 0.5077 - sparse_top_k_categorical_accuracy: 0.8546 - val_loss: 1.0740 - val_sparse_categorical_accuracy: 0.7004 - val_sparse_top_k_categorical_accuracy: 0.8918
# Epoch 32/500
# 49988/49988 - 6s - loss: 1.6007 - sparse_categorical_accuracy: 0.5050 - sparse_top_k_categorical_accuracy: 0.8544 - val_loss: 1.1004 - val_sparse_categorical_accuracy: 0.6885 - val_sparse_top_k_categorical_accuracy: 0.8827
# Epoch 33/500
# 49988/49988 - 5s - loss: 1.5856 - sparse_categorical_accuracy: 0.5090 - sparse_top_k_categorical_accuracy: 0.8551 - val_loss: 1.0390 - val_sparse_categorical_accuracy: 0.7202 - val_sparse_top_k_categorical_accuracy: 0.8802
# Epoch 34/500
# 49988/49988 - 5s - loss: 1.5782 - sparse_categorical_accuracy: 0.5106 - sparse_top_k_categorical_accuracy: 0.8575 - val_loss: 1.0361 - val_sparse_categorical_accuracy: 0.6886 - val_sparse_top_k_categorical_accuracy: 0.8907
# Epoch 35/500
# 49988/49988 - 5s - loss: 1.5827 - sparse_categorical_accuracy: 0.5072 - sparse_top_k_categorical_accuracy: 0.8574 - val_loss: 0.9939 - val_sparse_categorical_accuracy: 0.7429 - val_sparse_top_k_categorical_accuracy: 0.8979
# Epoch 36/500
# 49988/49988 - 5s - loss: 1.5824 - sparse_categorical_accuracy: 0.5103 - sparse_top_k_categorical_accuracy: 0.8548 - val_loss: 1.0131 - val_sparse_categorical_accuracy: 0.7515 - val_sparse_top_k_categorical_accuracy: 0.9020
# Epoch 37/500
# 49988/49988 - 5s - loss: 1.5689 - sparse_categorical_accuracy: 0.5141 - sparse_top_k_categorical_accuracy: 0.8575 - val_loss: 1.0604 - val_sparse_categorical_accuracy: 0.6938 - val_sparse_top_k_categorical_accuracy: 0.8902
# Epoch 38/500
# Restoring model weights from the end of the best epoch.
# 49988/49988 - 5s - loss: 1.5771 - sparse_categorical_accuracy: 0.5090 - sparse_top_k_categorical_accuracy: 0.8576 - val_loss: 1.2143 - val_sparse_categorical_accuracy: 0.6437 - val_sparse_top_k_categorical_accuracy: 0.8379
# Epoch 00038: early stopping
# FITTING NN ON BOOTSTRAP 4
#
#
# Train on 49988 samples, validate on 53363 samples
# Epoch 1/500
# 49988/49988 - 6s - loss: 3.3787 - sparse_categorical_accuracy: 0.4050 - sparse_top_k_categorical_accuracy: 0.7699 - val_loss: 1.4560 - val_sparse_categorical_accuracy: 0.6351 - val_sparse_top_k_categorical_accuracy: 0.8286
# Epoch 2/500
# 49988/49988 - 5s - loss: 1.8436 - sparse_categorical_accuracy: 0.4588 - sparse_top_k_categorical_accuracy: 0.8281 - val_loss: 1.3069 - val_sparse_categorical_accuracy: 0.7014 - val_sparse_top_k_categorical_accuracy: 0.8219
# Epoch 3/500
# 49988/49988 - 5s - loss: 1.7627 - sparse_categorical_accuracy: 0.4684 - sparse_top_k_categorical_accuracy: 0.8349 - val_loss: 1.4950 - val_sparse_categorical_accuracy: 0.6112 - val_sparse_top_k_categorical_accuracy: 0.7954
# Epoch 4/500
# 49988/49988 - 5s - loss: 1.7531 - sparse_categorical_accuracy: 0.4727 - sparse_top_k_categorical_accuracy: 0.8364 - val_loss: 1.2841 - val_sparse_categorical_accuracy: 0.6339 - val_sparse_top_k_categorical_accuracy: 0.8026
# Epoch 5/500
# 49988/49988 - 5s - loss: 1.7313 - sparse_categorical_accuracy: 0.4722 - sparse_top_k_categorical_accuracy: 0.8374 - val_loss: 1.5292 - val_sparse_categorical_accuracy: 0.6192 - val_sparse_top_k_categorical_accuracy: 0.8084
# Epoch 6/500
# 49988/49988 - 5s - loss: 1.7468 - sparse_categorical_accuracy: 0.4787 - sparse_top_k_categorical_accuracy: 0.8389 - val_loss: 1.2192 - val_sparse_categorical_accuracy: 0.6751 - val_sparse_top_k_categorical_accuracy: 0.8508
# Epoch 7/500
# 49988/49988 - 5s - loss: 1.7600 - sparse_categorical_accuracy: 0.4742 - sparse_top_k_categorical_accuracy: 0.8363 - val_loss: 1.2567 - val_sparse_categorical_accuracy: 0.6526 - val_sparse_top_k_categorical_accuracy: 0.8130
# Epoch 8/500
# 49988/49988 - 5s - loss: 1.6951 - sparse_categorical_accuracy: 0.4805 - sparse_top_k_categorical_accuracy: 0.8430 - val_loss: 1.1575 - val_sparse_categorical_accuracy: 0.6990 - val_sparse_top_k_categorical_accuracy: 0.8541
# Epoch 9/500
# 49988/49988 - 5s - loss: 1.6832 - sparse_categorical_accuracy: 0.4833 - sparse_top_k_categorical_accuracy: 0.8447 - val_loss: 1.2122 - val_sparse_categorical_accuracy: 0.6812 - val_sparse_top_k_categorical_accuracy: 0.8423
# Epoch 10/500
# 49988/49988 - 5s - loss: 1.6712 - sparse_categorical_accuracy: 0.4885 - sparse_top_k_categorical_accuracy: 0.8453 - val_loss: 1.1087 - val_sparse_categorical_accuracy: 0.7249 - val_sparse_top_k_categorical_accuracy: 0.8708
# Epoch 11/500
# 49988/49988 - 5s - loss: 1.6791 - sparse_categorical_accuracy: 0.4862 - sparse_top_k_categorical_accuracy: 0.8470 - val_loss: 1.3069 - val_sparse_categorical_accuracy: 0.6348 - val_sparse_top_k_categorical_accuracy: 0.8613
# Epoch 12/500
# 49988/49988 - 5s - loss: 1.6994 - sparse_categorical_accuracy: 0.4832 - sparse_top_k_categorical_accuracy: 0.8447 - val_loss: 1.3723 - val_sparse_categorical_accuracy: 0.6479 - val_sparse_top_k_categorical_accuracy: 0.8058
# Epoch 13/500
# 49988/49988 - 5s - loss: 1.7023 - sparse_categorical_accuracy: 0.4847 - sparse_top_k_categorical_accuracy: 0.8459 - val_loss: 1.3017 - val_sparse_categorical_accuracy: 0.7503 - val_sparse_top_k_categorical_accuracy: 0.8485
# Epoch 14/500
# 49988/49988 - 5s - loss: 1.6509 - sparse_categorical_accuracy: 0.4942 - sparse_top_k_categorical_accuracy: 0.8488 - val_loss: 0.9835 - val_sparse_categorical_accuracy: 0.7551 - val_sparse_top_k_categorical_accuracy: 0.9079
# Epoch 15/500
# 49988/49988 - 5s - loss: 1.6545 - sparse_categorical_accuracy: 0.4977 - sparse_top_k_categorical_accuracy: 0.8527 - val_loss: 1.0467 - val_sparse_categorical_accuracy: 0.7346 - val_sparse_top_k_categorical_accuracy: 0.8914
# Epoch 16/500
# 49988/49988 - 5s - loss: 1.6549 - sparse_categorical_accuracy: 0.4940 - sparse_top_k_categorical_accuracy: 0.8494 - val_loss: 1.1918 - val_sparse_categorical_accuracy: 0.7316 - val_sparse_top_k_categorical_accuracy: 0.8519
# Epoch 17/500
# 49988/49988 - 5s - loss: 1.6492 - sparse_categorical_accuracy: 0.4955 - sparse_top_k_categorical_accuracy: 0.8487 - val_loss: 0.9625 - val_sparse_categorical_accuracy: 0.7602 - val_sparse_top_k_categorical_accuracy: 0.9212
# Epoch 18/500
# 49988/49988 - 5s - loss: 1.6489 - sparse_categorical_accuracy: 0.4974 - sparse_top_k_categorical_accuracy: 0.8498 - val_loss: 1.1084 - val_sparse_categorical_accuracy: 0.6996 - val_sparse_top_k_categorical_accuracy: 0.8780
# Epoch 19/500
# 49988/49988 - 5s - loss: 1.6328 - sparse_categorical_accuracy: 0.4984 - sparse_top_k_categorical_accuracy: 0.8531 - val_loss: 1.1086 - val_sparse_categorical_accuracy: 0.6598 - val_sparse_top_k_categorical_accuracy: 0.8639
# Epoch 20/500
# 49988/49988 - 5s - loss: 1.6389 - sparse_categorical_accuracy: 0.4990 - sparse_top_k_categorical_accuracy: 0.8537 - val_loss: 1.0576 - val_sparse_categorical_accuracy: 0.7454 - val_sparse_top_k_categorical_accuracy: 0.8797
# Epoch 21/500
# 49988/49988 - 6s - loss: 1.6369 - sparse_categorical_accuracy: 0.4984 - sparse_top_k_categorical_accuracy: 0.8511 - val_loss: 1.1994 - val_sparse_categorical_accuracy: 0.7097 - val_sparse_top_k_categorical_accuracy: 0.8508
# Epoch 22/500
# 49988/49988 - 5s - loss: 1.6205 - sparse_categorical_accuracy: 0.5003 - sparse_top_k_categorical_accuracy: 0.8518 - val_loss: 1.2848 - val_sparse_categorical_accuracy: 0.7237 - val_sparse_top_k_categorical_accuracy: 0.8467
# Epoch 23/500
# 49988/49988 - 5s - loss: 1.6210 - sparse_categorical_accuracy: 0.5026 - sparse_top_k_categorical_accuracy: 0.8536 - val_loss: 1.1144 - val_sparse_categorical_accuracy: 0.7307 - val_sparse_top_k_categorical_accuracy: 0.8713
# Epoch 24/500
# 49988/49988 - 5s - loss: 1.6162 - sparse_categorical_accuracy: 0.5006 - sparse_top_k_categorical_accuracy: 0.8527 - val_loss: 1.0904 - val_sparse_categorical_accuracy: 0.6982 - val_sparse_top_k_categorical_accuracy: 0.8733
# Epoch 25/500
# 49988/49988 - 5s - loss: 1.6093 - sparse_categorical_accuracy: 0.5048 - sparse_top_k_categorical_accuracy: 0.8541 - val_loss: 1.0536 - val_sparse_categorical_accuracy: 0.7400 - val_sparse_top_k_categorical_accuracy: 0.8835
# Epoch 26/500
# 49988/49988 - 5s - loss: 1.6192 - sparse_categorical_accuracy: 0.5017 - sparse_top_k_categorical_accuracy: 0.8514 - val_loss: 1.1318 - val_sparse_categorical_accuracy: 0.6781 - val_sparse_top_k_categorical_accuracy: 0.8604
# Epoch 27/500
# Restoring model weights from the end of the best epoch.
# 49988/49988 - 5s - loss: 1.6210 - sparse_categorical_accuracy: 0.5018 - sparse_top_k_categorical_accuracy: 0.8516 - val_loss: 1.1389 - val_sparse_categorical_accuracy: 0.7578 - val_sparse_top_k_categorical_accuracy: 0.8544
# Epoch 00027: early stopping
# FITTING NN ON BOOTSTRAP 5
#
#
# Train on 49988 samples, validate on 53363 samples
# Epoch 1/500
# 49988/49988 - 6s - loss: 3.3300 - sparse_categorical_accuracy: 0.3949 - sparse_top_k_categorical_accuracy: 0.7671 - val_loss: 1.4526 - val_sparse_categorical_accuracy: 0.5940 - val_sparse_top_k_categorical_accuracy: 0.8162
# Epoch 2/500
# 49988/49988 - 5s - loss: 1.8327 - sparse_categorical_accuracy: 0.4561 - sparse_top_k_categorical_accuracy: 0.8261 - val_loss: 1.2629 - val_sparse_categorical_accuracy: 0.6371 - val_sparse_top_k_categorical_accuracy: 0.8255
# Epoch 3/500
# 49988/49988 - 5s - loss: 1.7661 - sparse_categorical_accuracy: 0.4629 - sparse_top_k_categorical_accuracy: 0.8307 - val_loss: 1.3270 - val_sparse_categorical_accuracy: 0.6401 - val_sparse_top_k_categorical_accuracy: 0.8021
# Epoch 4/500
# 49988/49988 - 5s - loss: 1.7344 - sparse_categorical_accuracy: 0.4706 - sparse_top_k_categorical_accuracy: 0.8352 - val_loss: 1.2579 - val_sparse_categorical_accuracy: 0.6214 - val_sparse_top_k_categorical_accuracy: 0.8244
# Epoch 5/500
# 49988/49988 - 5s - loss: 1.7251 - sparse_categorical_accuracy: 0.4730 - sparse_top_k_categorical_accuracy: 0.8358 - val_loss: 1.2233 - val_sparse_categorical_accuracy: 0.6412 - val_sparse_top_k_categorical_accuracy: 0.8387
# Epoch 6/500
# 49988/49988 - 5s - loss: 1.7156 - sparse_categorical_accuracy: 0.4735 - sparse_top_k_categorical_accuracy: 0.8392 - val_loss: 1.3936 - val_sparse_categorical_accuracy: 0.6305 - val_sparse_top_k_categorical_accuracy: 0.8209
# Epoch 7/500
# 49988/49988 - 5s - loss: 1.6990 - sparse_categorical_accuracy: 0.4752 - sparse_top_k_categorical_accuracy: 0.8409 - val_loss: 1.2354 - val_sparse_categorical_accuracy: 0.6205 - val_sparse_top_k_categorical_accuracy: 0.8465
# Epoch 8/500
# 49988/49988 - 5s - loss: 1.6926 - sparse_categorical_accuracy: 0.4764 - sparse_top_k_categorical_accuracy: 0.8415 - val_loss: 1.1222 - val_sparse_categorical_accuracy: 0.6578 - val_sparse_top_k_categorical_accuracy: 0.8874
# Epoch 9/500
# 49988/49988 - 5s - loss: 1.6811 - sparse_categorical_accuracy: 0.4809 - sparse_top_k_categorical_accuracy: 0.8446 - val_loss: 1.2100 - val_sparse_categorical_accuracy: 0.6664 - val_sparse_top_k_categorical_accuracy: 0.8521
# Epoch 10/500
# 49988/49988 - 5s - loss: 1.7134 - sparse_categorical_accuracy: 0.4740 - sparse_top_k_categorical_accuracy: 0.8397 - val_loss: 1.1577 - val_sparse_categorical_accuracy: 0.6942 - val_sparse_top_k_categorical_accuracy: 0.8946
# Epoch 11/500
# 49988/49988 - 5s - loss: 1.6808 - sparse_categorical_accuracy: 0.4833 - sparse_top_k_categorical_accuracy: 0.8424 - val_loss: 1.1453 - val_sparse_categorical_accuracy: 0.7201 - val_sparse_top_k_categorical_accuracy: 0.8654
# Epoch 12/500
# 49988/49988 - 5s - loss: 1.6680 - sparse_categorical_accuracy: 0.4867 - sparse_top_k_categorical_accuracy: 0.8461 - val_loss: 1.2226 - val_sparse_categorical_accuracy: 0.6721 - val_sparse_top_k_categorical_accuracy: 0.8306
# Epoch 13/500
# 49988/49988 - 5s - loss: 1.6505 - sparse_categorical_accuracy: 0.4912 - sparse_top_k_categorical_accuracy: 0.8487 - val_loss: 1.2571 - val_sparse_categorical_accuracy: 0.6364 - val_sparse_top_k_categorical_accuracy: 0.8316
# Epoch 14/500
# 49988/49988 - 5s - loss: 1.6549 - sparse_categorical_accuracy: 0.4880 - sparse_top_k_categorical_accuracy: 0.8459 - val_loss: 1.1924 - val_sparse_categorical_accuracy: 0.6689 - val_sparse_top_k_categorical_accuracy: 0.8460
# Epoch 15/500
# 49988/49988 - 5s - loss: 1.6441 - sparse_categorical_accuracy: 0.4930 - sparse_top_k_categorical_accuracy: 0.8494 - val_loss: 1.0814 - val_sparse_categorical_accuracy: 0.6560 - val_sparse_top_k_categorical_accuracy: 0.8923
# Epoch 16/500
# 49988/49988 - 5s - loss: 1.6470 - sparse_categorical_accuracy: 0.4932 - sparse_top_k_categorical_accuracy: 0.8466 - val_loss: 1.0228 - val_sparse_categorical_accuracy: 0.7523 - val_sparse_top_k_categorical_accuracy: 0.9017
# Epoch 17/500
# 49988/49988 - 5s - loss: 1.6402 - sparse_categorical_accuracy: 0.4918 - sparse_top_k_categorical_accuracy: 0.8477 - val_loss: 1.1452 - val_sparse_categorical_accuracy: 0.6638 - val_sparse_top_k_categorical_accuracy: 0.8555
# Epoch 18/500
# 49988/49988 - 5s - loss: 1.6328 - sparse_categorical_accuracy: 0.4947 - sparse_top_k_categorical_accuracy: 0.8491 - val_loss: 1.0656 - val_sparse_categorical_accuracy: 0.7430 - val_sparse_top_k_categorical_accuracy: 0.8869
# Epoch 19/500
# 49988/49988 - 5s - loss: 1.6201 - sparse_categorical_accuracy: 0.4990 - sparse_top_k_categorical_accuracy: 0.8510 - val_loss: 1.0863 - val_sparse_categorical_accuracy: 0.7017 - val_sparse_top_k_categorical_accuracy: 0.8769
# Epoch 20/500
# ...
# [41]	validation_0-merror:0.330266	validation_0-mlogloss:1.03317
# [42]	validation_0-merror:0.329704	validation_0-mlogloss:1.03177
# [43]	validation_0-merror:0.328317	validation_0-mlogloss:1.02641
# [44]	validation_0-merror:0.328092	validation_0-mlogloss:1.02645
# [45]	validation_0-merror:0.326818	validation_0-mlogloss:1.01916
# [46]	validation_0-merror:0.325113	validation_0-mlogloss:1.01265
# [47]	validation_0-merror:0.323183	validation_0-mlogloss:1.00574
# [48]	validation_0-merror:0.322733	validation_0-mlogloss:1.00428
# [49]	validation_0-merror:0.321384	validation_0-mlogloss:0.998474
# [50]	validation_0-merror:0.320109	validation_0-mlogloss:0.993553
# [51]	validation_0-merror:0.319266	validation_0-mlogloss:0.990418
# [52]	validation_0-merror:0.319416	validation_0-mlogloss:0.989193
# [53]	validation_0-merror:0.318985	validation_0-mlogloss:0.985528
# [54]	validation_0-merror:0.31861	validation_0-mlogloss:0.984566
# [55]	validation_0-merror:0.318067	validation_0-mlogloss:0.979437
# [56]	validation_0-merror:0.317336	validation_0-mlogloss:0.976478
# [57]	validation_0-merror:0.316886	validation_0-mlogloss:0.976432
# [58]	validation_0-merror:0.315912	validation_0-mlogloss:0.972531
# [59]	validation_0-merror:0.315125	validation_0-mlogloss:0.969135
# [60]	validation_0-merror:0.314787	validation_0-mlogloss:0.969136
# [61]	validation_0-merror:0.313476	validation_0-mlogloss:0.965021
# [62]	validation_0-merror:0.311864	validation_0-mlogloss:0.961453
# [63]	validation_0-merror:0.310571	validation_0-mlogloss:0.958394
# [64]	validation_0-merror:0.309821	validation_0-mlogloss:0.956813
# [65]	validation_0-merror:0.309465	validation_0-mlogloss:0.953672
# [66]	validation_0-merror:0.309428	validation_0-mlogloss:0.952967
# [67]	validation_0-merror:0.309372	validation_0-mlogloss:0.95224
# [68]	validation_0-merror:0.308922	validation_0-mlogloss:0.951854
# [69]	validation_0-merror:0.308435	validation_0-mlogloss:0.949865
# [70]	validation_0-merror:0.307123	validation_0-mlogloss:0.946995
# [71]	validation_0-merror:0.306842	validation_0-mlogloss:0.946254
# [72]	validation_0-merror:0.305436	validation_0-mlogloss:0.941317
# [73]	validation_0-merror:0.304481	validation_0-mlogloss:0.938973
# [74]	validation_0-merror:0.30478	validation_0-mlogloss:0.939367
# [75]	validation_0-merror:0.304499	validation_0-mlogloss:0.938826
# [76]	validation_0-merror:0.3042	validation_0-mlogloss:0.936973
# [77]	validation_0-merror:0.303019	validation_0-mlogloss:0.933145
# [78]	validation_0-merror:0.302775	validation_0-mlogloss:0.932784
# [79]	validation_0-merror:0.302419	validation_0-mlogloss:0.9329
# [80]	validation_0-merror:0.30197	validation_0-mlogloss:0.931311
# [81]	validation_0-merror:0.300658	validation_0-mlogloss:0.926633
# [82]	validation_0-merror:0.300452	validation_0-mlogloss:0.927384
# [83]	validation_0-merror:0.299646	validation_0-mlogloss:0.926238
# [84]	validation_0-merror:0.299833	validation_0-mlogloss:0.925838
# [85]	validation_0-merror:0.29944	validation_0-mlogloss:0.923873
# [86]	validation_0-merror:0.29899	validation_0-mlogloss:0.923765
# [87]	validation_0-merror:0.298596	validation_0-mlogloss:0.921553
# [88]	validation_0-merror:0.297547	validation_0-mlogloss:0.918625
# [89]	validation_0-merror:0.297697	validation_0-mlogloss:0.918203
# [90]	validation_0-merror:0.297753	validation_0-mlogloss:0.91772
# [91]	validation_0-merror:0.297135	validation_0-mlogloss:0.91691
# [92]	validation_0-merror:0.297266	validation_0-mlogloss:0.916257
# [93]	validation_0-merror:0.296966	validation_0-mlogloss:0.916041
# [94]	validation_0-merror:0.296629	validation_0-mlogloss:0.914505
# [95]	validation_0-merror:0.296142	validation_0-mlogloss:0.913289
# [96]	validation_0-merror:0.295767	validation_0-mlogloss:0.912657
# [97]	validation_0-merror:0.295111	validation_0-mlogloss:0.911581
# [98]	validation_0-merror:0.294961	validation_0-mlogloss:0.910472
# [99]	validation_0-merror:0.295298	validation_0-mlogloss:0.910589
# [100]	validation_0-merror:0.294736	validation_0-mlogloss:0.909664
# [101]	validation_0-merror:0.294436	validation_0-mlogloss:0.908654
# [102]	validation_0-merror:0.294005	validation_0-mlogloss:0.908566
# [103]	validation_0-merror:0.293968	validation_0-mlogloss:0.907601
# [104]	validation_0-merror:0.293986	validation_0-mlogloss:0.90762
# [105]	validation_0-merror:0.29393	validation_0-mlogloss:0.907357
# [106]	validation_0-merror:0.293612	validation_0-mlogloss:0.906659
# [107]	validation_0-merror:0.293368	validation_0-mlogloss:0.905881
# [108]	validation_0-merror:0.29215	validation_0-mlogloss:0.90453
# [109]	validation_0-merror:0.292431	validation_0-mlogloss:0.904487
# [110]	validation_0-merror:0.291719	validation_0-mlogloss:0.903123
# [111]	validation_0-merror:0.291026	validation_0-mlogloss:0.901827
# [112]	validation_0-merror:0.290651	validation_0-mlogloss:0.901655
# [113]	validation_0-merror:0.290782	validation_0-mlogloss:0.901669
# [114]	validation_0-merror:0.289714	validation_0-mlogloss:0.898866
# [115]	validation_0-merror:0.28917	validation_0-mlogloss:0.897714
# [116]	validation_0-merror:0.288683	validation_0-mlogloss:0.895753
# [117]	validation_0-merror:0.288721	validation_0-mlogloss:0.895329
# [118]	validation_0-merror:0.288383	validation_0-mlogloss:0.894358
# [119]	validation_0-merror:0.288477	validation_0-mlogloss:0.894808
# [120]	validation_0-merror:0.287784	validation_0-mlogloss:0.893025
# [121]	validation_0-merror:0.288046	validation_0-mlogloss:0.893088
# [122]	validation_0-merror:0.288102	validation_0-mlogloss:0.892498
# [123]	validation_0-merror:0.287859	validation_0-mlogloss:0.892005
# [124]	validation_0-merror:0.287559	validation_0-mlogloss:0.892353
# [125]	validation_0-merror:0.287765	validation_0-mlogloss:0.892654
# [126]	validation_0-merror:0.287147	validation_0-mlogloss:0.890002
# [127]	validation_0-merror:0.286922	validation_0-mlogloss:0.890516
# [128]	validation_0-merror:0.286509	validation_0-mlogloss:0.888314
# [129]	validation_0-merror:0.286547	validation_0-mlogloss:0.887767
# [130]	validation_0-merror:0.285891	validation_0-mlogloss:0.887732
# [131]	validation_0-merror:0.286097	validation_0-mlogloss:0.88773
# [132]	validation_0-merror:0.286078	validation_0-mlogloss:0.887653
# [133]	validation_0-merror:0.286116	validation_0-mlogloss:0.887581
# [134]	validation_0-merror:0.285966	validation_0-mlogloss:0.887215
# [135]	validation_0-merror:0.28546	validation_0-mlogloss:0.886906
# [136]	validation_0-merror:0.285629	validation_0-mlogloss:0.886773
# [137]	validation_0-merror:0.285685	validation_0-mlogloss:0.88667
# [138]	validation_0-merror:0.285572	validation_0-mlogloss:0.886983
# [139]	validation_0-merror:0.284991	validation_0-mlogloss:0.886684
# [140]	validation_0-merror:0.284842	validation_0-mlogloss:0.88587
# [141]	validation_0-merror:0.284486	validation_0-mlogloss:0.884327
# [142]	validation_0-merror:0.284223	validation_0-mlogloss:0.884658
# [143]	validation_0-merror:0.284129	validation_0-mlogloss:0.88444
# [144]	validation_0-merror:0.284054	validation_0-mlogloss:0.884264
# [145]	validation_0-merror:0.283811	validation_0-mlogloss:0.883855
# [146]	validation_0-merror:0.283623	validation_0-mlogloss:0.883899
# [147]	validation_0-merror:0.283792	validation_0-mlogloss:0.884237
# [148]	validation_0-merror:0.283549	validation_0-mlogloss:0.883889
# [149]	validation_0-merror:0.283211	validation_0-mlogloss:0.883866
# [150]	validation_0-merror:0.28338	validation_0-mlogloss:0.884401
# [151]	validation_0-merror:0.283342	validation_0-mlogloss:0.883797
# [152]	validation_0-merror:0.28323	validation_0-mlogloss:0.883705
# [153]	validation_0-merror:0.282893	validation_0-mlogloss:0.883339
# [154]	validation_0-merror:0.28263	validation_0-mlogloss:0.883527
# [155]	validation_0-merror:0.282537	validation_0-mlogloss:0.8827
# [156]	validation_0-merror:0.282256	validation_0-mlogloss:0.882832
# [157]	validation_0-merror:0.282387	validation_0-mlogloss:0.883
# [158]	validation_0-merror:0.282574	validation_0-mlogloss:0.882886
# [159]	validation_0-merror:0.282593	validation_0-mlogloss:0.882648
# [160]	validation_0-merror:0.281974	validation_0-mlogloss:0.881356
# [161]	validation_0-merror:0.281956	validation_0-mlogloss:0.881695
# [162]	validation_0-merror:0.281899	validation_0-mlogloss:0.881506
# [163]	validation_0-merror:0.281787	validation_0-mlogloss:0.880599
# [164]	validation_0-merror:0.281618	validation_0-mlogloss:0.881075
# [165]	validation_0-merror:0.281431	validation_0-mlogloss:0.880676
# [166]	validation_0-merror:0.281618	validation_0-mlogloss:0.881012
# [167]	validation_0-merror:0.281412	validation_0-mlogloss:0.881257
# [168]	validation_0-merror:0.282143	validation_0-mlogloss:0.881489
# [169]	validation_0-merror:0.281918	validation_0-mlogloss:0.881196
# [170]	validation_0-merror:0.281918	validation_0-mlogloss:0.881177
# [171]	validation_0-merror:0.281525	validation_0-mlogloss:0.881177
# [172]	validation_0-merror:0.282293	validation_0-mlogloss:0.882033
# [173]	validation_0-merror:0.281525	validation_0-mlogloss:0.881282
# [174]	validation_0-merror:0.281712	validation_0-mlogloss:0.881488
# [175]	validation_0-merror:0.281393	validation_0-mlogloss:0.88135
# [176]	validation_0-merror:0.281319	validation_0-mlogloss:0.880979
# [177]	validation_0-merror:0.281225	validation_0-mlogloss:0.880698
# [178]	validation_0-merror:0.280775	validation_0-mlogloss:0.880473
# [179]	validation_0-merror:0.280831	validation_0-mlogloss:0.880502
# [180]	validation_0-merror:0.280438	validation_0-mlogloss:0.880415
# [181]	validation_0-merror:0.280644	validation_0-mlogloss:0.880446
# [182]	validation_0-merror:0.280288	validation_0-mlogloss:0.880103
# [183]	validation_0-merror:0.280157	validation_0-mlogloss:0.879499
# [184]	validation_0-merror:0.2801	validation_0-mlogloss:0.879437
# [185]	validation_0-merror:0.279838	validation_0-mlogloss:0.878966
# [186]	validation_0-merror:0.279782	validation_0-mlogloss:0.879016
# [187]	validation_0-merror:0.279763	validation_0-mlogloss:0.879522
# [188]	validation_0-merror:0.279913	validation_0-mlogloss:0.879746
# [189]	validation_0-merror:0.279801	validation_0-mlogloss:0.879728
# [190]	validation_0-merror:0.27952	validation_0-mlogloss:0.879728
# [191]	validation_0-merror:0.279669	validation_0-mlogloss:0.879812
# [192]	validation_0-merror:0.279594	validation_0-mlogloss:0.87997
# [193]	validation_0-merror:0.279482	validation_0-mlogloss:0.880094
# [194]	validation_0-merror:0.279744	validation_0-mlogloss:0.8803
# [195]	validation_0-merror:0.279088	validation_0-mlogloss:0.878827
# [196]	validation_0-merror:0.278845	validation_0-mlogloss:0.878759
# [197]	validation_0-merror:0.27877	validation_0-mlogloss:0.878844
# [198]	validation_0-merror:0.278826	validation_0-mlogloss:0.87879
# [199]	validation_0-merror:0.278732	validation_0-mlogloss:0.878482
# [200]	validation_0-merror:0.278695	validation_0-mlogloss:0.878263
# [201]	validation_0-merror:0.27877	validation_0-mlogloss:0.878735
# [202]	validation_0-merror:0.278732	validation_0-mlogloss:0.879175
# [203]	validation_0-merror:0.278676	validation_0-mlogloss:0.878719
# [204]	validation_0-merror:0.278451	validation_0-mlogloss:0.878611
# [205]	validation_0-merror:0.278583	validation_0-mlogloss:0.878948
# [206]	validation_0-merror:0.278433	validation_0-mlogloss:0.878625
# [207]	validation_0-merror:0.278283	validation_0-mlogloss:0.878423
# [208]	validation_0-merror:0.278395	validation_0-mlogloss:0.878942
# [209]	validation_0-merror:0.278433	validation_0-mlogloss:0.878598
# [210]	validation_0-merror:0.278189	validation_0-mlogloss:0.878728
# [211]	validation_0-merror:0.277852	validation_0-mlogloss:0.878501
# [212]	validation_0-merror:0.277983	validation_0-mlogloss:0.878714
# [213]	validation_0-merror:0.277777	validation_0-mlogloss:0.878636
# [214]	validation_0-merror:0.277664	validation_0-mlogloss:0.878553
# [215]	validation_0-merror:0.277758	validation_0-mlogloss:0.879011
# [216]	validation_0-merror:0.277721	validation_0-mlogloss:0.878802
# [217]	validation_0-merror:0.277683	validation_0-mlogloss:0.879301
# [218]	validation_0-merror:0.277683	validation_0-mlogloss:0.878916
# [219]	validation_0-merror:0.277496	validation_0-mlogloss:0.878668
# [220]	validation_0-merror:0.277364	validation_0-mlogloss:0.878413
# [221]	validation_0-merror:0.277383	validation_0-mlogloss:0.878983
# [222]	validation_0-merror:0.27729	validation_0-mlogloss:0.87864
# [223]	validation_0-merror:0.27699	validation_0-mlogloss:0.878099
# [224]	validation_0-merror:0.277008	validation_0-mlogloss:0.877973
# [225]	validation_0-merror:0.276709	validation_0-mlogloss:0.877573
# [226]	validation_0-merror:0.276709	validation_0-mlogloss:0.877609
# [227]	validation_0-merror:0.276877	validation_0-mlogloss:0.877691
# [228]	validation_0-merror:0.276671	validation_0-mlogloss:0.877315
# [229]	validation_0-merror:0.27654	validation_0-mlogloss:0.877283
# [230]	validation_0-merror:0.276315	validation_0-mlogloss:0.877657
# [231]	validation_0-merror:0.276502	validation_0-mlogloss:0.877762
# [232]	validation_0-merror:0.276409	validation_0-mlogloss:0.877505
# [233]	validation_0-merror:0.276484	validation_0-mlogloss:0.877958
# [234]	validation_0-merror:0.27654	validation_0-mlogloss:0.878101
# [235]	validation_0-merror:0.276484	validation_0-mlogloss:0.87811
# [236]	validation_0-merror:0.276221	validation_0-mlogloss:0.878372
# [237]	validation_0-merror:0.276296	validation_0-mlogloss:0.878595
# [238]	validation_0-merror:0.27609	validation_0-mlogloss:0.878942
# [239]	validation_0-merror:0.27624	validation_0-mlogloss:0.879456
# [240]	validation_0-merror:0.275903	validation_0-mlogloss:0.879381
# [241]	validation_0-merror:0.276015	validation_0-mlogloss:0.879294
# [242]	validation_0-merror:0.276053	validation_0-mlogloss:0.879928
# [243]	validation_0-merror:0.27564	validation_0-mlogloss:0.87959
# [244]	validation_0-merror:0.27564	validation_0-mlogloss:0.879899
# [245]	validation_0-merror:0.275509	validation_0-mlogloss:0.880164
# [246]	validation_0-merror:0.275359	validation_0-mlogloss:0.880475
# [247]	validation_0-merror:0.275359	validation_0-mlogloss:0.880264
# [248]	validation_0-merror:0.275359	validation_0-mlogloss:0.88023
# [249]	validation_0-merror:0.275472	validation_0-mlogloss:0.880081
# [250]	validation_0-merror:0.275078	validation_0-mlogloss:0.879814
# [251]	validation_0-merror:0.275097	validation_0-mlogloss:0.880242
# [252]	validation_0-merror:0.275378	validation_0-mlogloss:0.880155
# [253]	validation_0-merror:0.275266	validation_0-mlogloss:0.880431
# [254]	validation_0-merror:0.275228	validation_0-mlogloss:0.880892
# [255]	validation_0-merror:0.275359	validation_0-mlogloss:0.881213
# [256]	validation_0-merror:0.275134	validation_0-mlogloss:0.88118
# [257]	validation_0-merror:0.274703	validation_0-mlogloss:0.881261
# [258]	validation_0-merror:0.274797	validation_0-mlogloss:0.881159
# [259]	validation_0-merror:0.274572	validation_0-mlogloss:0.881563
# [260]	validation_0-merror:0.274741	validation_0-mlogloss:0.881766
# [261]	validation_0-merror:0.274947	validation_0-mlogloss:0.882231
# [262]	validation_0-merror:0.274647	validation_0-mlogloss:0.882212
# [263]	validation_0-merror:0.274516	validation_0-mlogloss:0.882124
# [264]	validation_0-merror:0.274591	validation_0-mlogloss:0.882438
# [265]	validation_0-merror:0.274479	validation_0-mlogloss:0.881814
# [266]	validation_0-merror:0.274554	validation_0-mlogloss:0.882388
# [267]	validation_0-merror:0.274666	validation_0-mlogloss:0.882172
# [268]	validation_0-merror:0.274591	validation_0-mlogloss:0.882473
# [269]	validation_0-merror:0.274703	validation_0-mlogloss:0.882716
# [270]	validation_0-merror:0.274628	validation_0-mlogloss:0.882614
# [271]	validation_0-merror:0.27446	validation_0-mlogloss:0.882898
# [272]	validation_0-merror:0.274479	validation_0-mlogloss:0.883389
# [273]	validation_0-merror:0.274572	validation_0-mlogloss:0.884083
# [274]	validation_0-merror:0.274516	validation_0-mlogloss:0.884288
# [275]	validation_0-merror:0.27416	validation_0-mlogloss:0.884303
# [276]	validation_0-merror:0.274254	validation_0-mlogloss:0.884713
# [277]	validation_0-merror:0.273879	validation_0-mlogloss:0.884727
# [278]	validation_0-merror:0.274048	validation_0-mlogloss:0.884685
# [279]	validation_0-merror:0.274048	validation_0-mlogloss:0.884886
# Stopping. Best iteration:
# [229]	validation_0-merror:0.27654	validation_0-mlogloss:0.877283
#
# FITTING ENSEMBLER...
# Computing preliminary predictions...
# EnsembleClassifier(BATCHSIZE=64, BOOTSTRAP_ITER=10, EPOCHS=500, hpo=False,
#                    load_models=False, random_state=42, save_models=True)

# %%
ens.score(X_val[:, xgb_features], y_val)
# Out:
# Computing preliminary predictions...
# 0.8351451913844551

# %%
cal_ens = CalibratedClassifierCV(ens, method='isotonic', cv='prefit')

# %%
cal_ens.fit(X_val[:, xgb_features], y_val)
# Out:
# Computing preliminary predictions...
# CalibratedClassifierCV(base_estimator=EnsembleClassifier(BATCHSIZE=64,
#                                                          BOOTSTRAP_ITER=10,
#                                                          EPOCHS=500, hpo=False,
#                                                          load_models=False,
#                                                          random_state=42,
#                                                          save_models=True),
#                        cv='prefit', method='isotonic')

# %% [markdown]
# This cell implements the second ensemble model described in the report by extending the previous class and overriding only two methods.

# %%
class EnsembleSingleModelsClassifier(EnsembleClassifier):
  @staticmethod
  def objective_fun(w, X, y, n_class):
    w = np.abs(w)
    sol = np.zeros((X.shape[0], n_class))
    for idx in range(len(w)):
      sol += X[:, idx*n_class:(idx+1)*n_class] * w[idx]
    if np.isnan(sol).any():
      return np.inf
    ll = log_loss(y, sol)
    return ll    


  def _fit_ensembler(self):
    X_probs = self.get_prediction_matrix(self.X_train_)
    x0 = np.random.uniform(size = len(self.nn_models_ + self.xgb_models_))
    bounds = [(0,1)]*len(x0)
    cons = ({'type': 'eq', 'fun': lambda w: 1-sum(w)})
    res = minimize(self.objective_fun, 
                    x0, 
                    args=(X_probs, self.y_train_, self.n_classes_), 
                    method='SLSQP', 
                    bounds=bounds
                   )
    self.w_ = res.x

# %%
ens2 = EnsembleSingleModelsClassifier(BOOTSTRAP_ITER=10, load_models=True)

# %%
ens2.fit(X_train[:, xgb_features], y_train, 
        X_val=X_val[:, xgb_features], 
        y_val=y_val)
# Out:
# LOADING NN 0...
#
#
# LOADING NN 1...
#
#
# LOADING NN 2...
#
#
# LOADING NN 3...
#
#
# LOADING NN 4...
#
#
# LOADING NN 5...
#
#
# LOADING NN 6...
#
#
# LOADING NN 7...
#
#
# LOADING NN 8...
#
#
# LOADING NN 9...
#
#
# LOADING XGB 0...
#
#
# LOADING XGB 1...
#
#
# LOADING XGB 2...
#
#
# LOADING XGB 3...
#
#
# LOADING XGB 4...
#
#
# LOADING XGB 5...
#
#
# LOADING XGB 6...
#
#
# LOADING XGB 7...
#
#
# LOADING XGB 8...
#
#
# LOADING XGB 9...
#
#
# FITTING ENSEMBLER...
# Computing preliminary predictions...
# EnsembleSingleModelsClassifier(BATCHSIZE=64, BOOTSTRAP_ITER=10, EPOCHS=500,
#                                hpo=False, load_models=True, random_state=42,
#                                save_models=False)

# %%
ens2.score(X_val[:, xgb_features], y_val)
# Out:
# Computing preliminary predictions...
# 0.7251559637858063

# %% [markdown]
# # RERUN WITH HPO
#
# ---

# %%
hpo_ens = EnsembleSingleModelsClassifier(BOOTSTRAP_ITER=2, load_models=False, 
                                         save_models=False, hpo=True)

# %%
hpo_ens.fit(X_train[:, xgb_features], y_train, 
        X_val=X_val[:, xgb_features], 
        y_val=y_val)
# Out:
# ENTERING HPO...
# FITTING XGB ON BOOTSTRAP 0
#
#
# [0]	validation_0-merror:0.367389	validation_0-mlogloss:2.14499
# Multiple eval metrics have been passed: 'validation_0-mlogloss' will be used for early stopping.
#
# Will train until validation_0-mlogloss hasn't improved in 50 rounds.
# [1]	validation_0-merror:0.357963	validation_0-mlogloss:1.95465
# [2]	validation_0-merror:0.355583	validation_0-mlogloss:1.82289
# [3]	validation_0-merror:0.356652	validation_0-mlogloss:1.72164
# [4]	validation_0-merror:0.351667	validation_0-mlogloss:1.63423
# [5]	validation_0-merror:0.34998	validation_0-mlogloss:1.56494
# [6]	validation_0-merror:0.346851	validation_0-mlogloss:1.50447
# [7]	validation_0-merror:0.34612	validation_0-mlogloss:1.45307
# [8]	validation_0-merror:0.342597	validation_0-mlogloss:1.40967
# [9]	validation_0-merror:0.342316	validation_0-mlogloss:1.37299
# [10]	validation_0-merror:0.341154	validation_0-mlogloss:1.33904
# [11]	validation_0-merror:0.340048	validation_0-mlogloss:1.31204
# [12]	validation_0-merror:0.338774	validation_0-mlogloss:1.28328
# [13]	validation_0-merror:0.338493	validation_0-mlogloss:1.25967
# [14]	validation_0-merror:0.337631	validation_0-mlogloss:1.23702
# [15]	validation_0-merror:0.336113	validation_0-mlogloss:1.21846
# [16]	validation_0-merror:0.336675	validation_0-mlogloss:1.20048
# [17]	validation_0-merror:0.336582	validation_0-mlogloss:1.18618
# [18]	validation_0-merror:0.335438	validation_0-mlogloss:1.164
# [19]	validation_0-merror:0.334689	validation_0-mlogloss:1.15365
# [20]	validation_0-merror:0.334783	validation_0-mlogloss:1.13966
# [21]	validation_0-merror:0.334501	validation_0-mlogloss:1.12764
# [22]	validation_0-merror:0.334295	validation_0-mlogloss:1.11647
# [23]	validation_0-merror:0.333902	validation_0-mlogloss:1.10777
# [24]	validation_0-merror:0.332196	validation_0-mlogloss:1.09117
# [25]	validation_0-merror:0.330323	validation_0-mlogloss:1.07981
# [26]	validation_0-merror:0.330023	validation_0-mlogloss:1.07129
# [27]	validation_0-merror:0.329386	validation_0-mlogloss:1.06332
# [28]	validation_0-merror:0.328973	validation_0-mlogloss:1.05744
# [29]	validation_0-merror:0.326518	validation_0-mlogloss:1.04503
# [30]	validation_0-merror:0.326556	validation_0-mlogloss:1.03807
# [31]	validation_0-merror:0.326631	validation_0-mlogloss:1.03374
# [32]	validation_0-merror:0.325975	validation_0-mlogloss:1.02503
# [33]	validation_0-merror:0.325094	validation_0-mlogloss:1.0224
# [34]	validation_0-merror:0.32605	validation_0-mlogloss:1.02032
# [35]	validation_0-merror:0.324851	validation_0-mlogloss:1.01049
# [36]	validation_0-merror:0.32412	validation_0-mlogloss:1.00332
# [37]	validation_0-merror:0.32412	validation_0-mlogloss:1.00116
# [38]	validation_0-merror:0.323464	validation_0-mlogloss:0.998345
# [39]	validation_0-merror:0.322152	validation_0-mlogloss:0.99578
# [40]	validation_0-merror:0.319866	validation_0-mlogloss:0.986931
# [41]	validation_0-merror:0.318404	validation_0-mlogloss:0.982344
# [42]	validation_0-merror:0.317074	validation_0-mlogloss:0.977458
# [43]	validation_0-merror:0.316942	validation_0-mlogloss:0.975827
# [44]	validation_0-merror:0.316212	validation_0-mlogloss:0.973413
# [45]	validation_0-merror:0.315649	validation_0-mlogloss:0.96781
# [46]	validation_0-merror:0.3155	validation_0-mlogloss:0.966765
# [47]	validation_0-merror:0.313494	validation_0-mlogloss:0.960183
# [48]	validation_0-merror:0.312201	validation_0-mlogloss:0.955461
# [49]	validation_0-merror:0.311808	validation_0-mlogloss:0.953597
# [50]	validation_0-merror:0.309522	validation_0-mlogloss:0.948688
# [51]	validation_0-merror:0.308716	validation_0-mlogloss:0.945777
# [52]	validation_0-merror:0.308229	validation_0-mlogloss:0.942896
# [53]	validation_0-merror:0.307198	validation_0-mlogloss:0.941089
# [54]	validation_0-merror:0.307685	validation_0-mlogloss:0.93953
# [55]	validation_0-merror:0.306355	validation_0-mlogloss:0.937297
# [56]	validation_0-merror:0.306336	validation_0-mlogloss:0.935672
# [57]	validation_0-merror:0.30508	validation_0-mlogloss:0.932856
# [58]	validation_0-merror:0.304237	validation_0-mlogloss:0.930024
# [59]	validation_0-merror:0.304368	validation_0-mlogloss:0.928684
# [60]	validation_0-merror:0.303412	validation_0-mlogloss:0.924431
# [61]	validation_0-merror:0.303225	validation_0-mlogloss:0.923604
# [62]	validation_0-merror:0.303206	validation_0-mlogloss:0.923428
# [63]	validation_0-merror:0.302082	validation_0-mlogloss:0.921273
# [64]	validation_0-merror:0.301707	validation_0-mlogloss:0.919548
# [65]	validation_0-merror:0.301688	validation_0-mlogloss:0.919003
# [66]	validation_0-merror:0.301407	validation_0-mlogloss:0.917354
# [67]	validation_0-merror:0.300639	validation_0-mlogloss:0.915109
# [68]	validation_0-merror:0.299946	validation_0-mlogloss:0.91429
# [69]	validation_0-merror:0.299234	validation_0-mlogloss:0.912632
# [70]	validation_0-merror:0.297716	validation_0-mlogloss:0.908343
# [71]	validation_0-merror:0.297678	validation_0-mlogloss:0.906995
# [72]	validation_0-merror:0.296516	validation_0-mlogloss:0.905495
# [73]	validation_0-merror:0.295317	validation_0-mlogloss:0.903942
# [74]	validation_0-merror:0.295298	validation_0-mlogloss:0.903237
# [75]	validation_0-merror:0.294792	validation_0-mlogloss:0.90126
# [76]	validation_0-merror:0.294811	validation_0-mlogloss:0.900851
# [77]	validation_0-merror:0.29483	validation_0-mlogloss:0.900208
# [78]	validation_0-merror:0.29483	validation_0-mlogloss:0.900205
# [79]	validation_0-merror:0.294343	validation_0-mlogloss:0.899534
# [80]	validation_0-merror:0.294399	validation_0-mlogloss:0.899603
# [81]	validation_0-merror:0.293818	validation_0-mlogloss:0.899033
# [82]	validation_0-merror:0.293368	validation_0-mlogloss:0.897185
# [83]	validation_0-merror:0.291794	validation_0-mlogloss:0.892402
# [84]	validation_0-merror:0.291869	validation_0-mlogloss:0.891827
# [85]	validation_0-merror:0.291438	validation_0-mlogloss:0.890637
# [86]	validation_0-merror:0.290726	validation_0-mlogloss:0.889222
# [87]	validation_0-merror:0.290014	validation_0-mlogloss:0.888274
# [88]	validation_0-merror:0.289957	validation_0-mlogloss:0.887433
# [89]	validation_0-merror:0.290126	validation_0-mlogloss:0.888182
# [90]	validation_0-merror:0.289864	validation_0-mlogloss:0.887502
# [91]	validation_0-merror:0.289339	validation_0-mlogloss:0.886532
# [92]	validation_0-merror:0.289264	validation_0-mlogloss:0.887256
# [93]	validation_0-merror:0.28902	validation_0-mlogloss:0.886104
# [94]	validation_0-merror:0.28844	validation_0-mlogloss:0.885571
# [95]	validation_0-merror:0.288158	validation_0-mlogloss:0.884822
# [96]	validation_0-merror:0.288233	validation_0-mlogloss:0.885038
# [97]	validation_0-merror:0.286734	validation_0-mlogloss:0.882394
# [98]	validation_0-merror:0.286678	validation_0-mlogloss:0.882315
# [99]	validation_0-merror:0.286584	validation_0-mlogloss:0.881777
# [100]	validation_0-merror:0.286416	validation_0-mlogloss:0.88182
# [101]	validation_0-merror:0.286678	validation_0-mlogloss:0.881753
# [102]	validation_0-merror:0.286078	validation_0-mlogloss:0.880865
# [103]	validation_0-merror:0.28561	validation_0-mlogloss:0.879578
# [104]	validation_0-merror:0.284767	validation_0-mlogloss:0.877859
# [105]	validation_0-merror:0.284448	validation_0-mlogloss:0.877432
# [106]	validation_0-merror:0.283961	validation_0-mlogloss:0.876672
# [107]	validation_0-merror:0.283399	validation_0-mlogloss:0.876358
# [108]	validation_0-merror:0.283324	validation_0-mlogloss:0.876116
# [109]	validation_0-merror:0.28338	validation_0-mlogloss:0.875918
# [110]	validation_0-merror:0.282387	validation_0-mlogloss:0.875508
# [111]	validation_0-merror:0.282162	validation_0-mlogloss:0.874753
# [112]	validation_0-merror:0.281843	validation_0-mlogloss:0.874787
# [113]	validation_0-merror:0.281937	validation_0-mlogloss:0.875343
# [114]	validation_0-merror:0.281862	validation_0-mlogloss:0.874813
# [115]	validation_0-merror:0.281768	validation_0-mlogloss:0.874669
# [116]	validation_0-merror:0.281881	validation_0-mlogloss:0.874104
# [117]	validation_0-merror:0.281881	validation_0-mlogloss:0.873851
# [118]	validation_0-merror:0.281393	validation_0-mlogloss:0.873422
# [119]	validation_0-merror:0.281375	validation_0-mlogloss:0.873712
# [120]	validation_0-merror:0.281468	validation_0-mlogloss:0.873489
# [121]	validation_0-merror:0.281094	validation_0-mlogloss:0.872464
# [122]	validation_0-merror:0.280663	validation_0-mlogloss:0.871719
# [123]	validation_0-merror:0.280269	validation_0-mlogloss:0.871598
# [124]	validation_0-merror:0.280138	validation_0-mlogloss:0.871525
# [125]	validation_0-merror:0.279951	validation_0-mlogloss:0.8708
# [126]	validation_0-merror:0.280007	validation_0-mlogloss:0.870543
# [127]	validation_0-merror:0.279051	validation_0-mlogloss:0.868684
# [128]	validation_0-merror:0.278826	validation_0-mlogloss:0.868379
# [129]	validation_0-merror:0.27832	validation_0-mlogloss:0.867015
# [130]	validation_0-merror:0.277983	validation_0-mlogloss:0.866401
# [131]	validation_0-merror:0.277664	validation_0-mlogloss:0.865061
# [132]	validation_0-merror:0.278376	validation_0-mlogloss:0.865529
# [133]	validation_0-merror:0.277908	validation_0-mlogloss:0.864967
# [134]	validation_0-merror:0.277702	validation_0-mlogloss:0.864966
# [135]	validation_0-merror:0.277233	validation_0-mlogloss:0.864345
# [136]	validation_0-merror:0.276427	validation_0-mlogloss:0.863
# [137]	validation_0-merror:0.276278	validation_0-mlogloss:0.8624
# [138]	validation_0-merror:0.276484	validation_0-mlogloss:0.86331
# [139]	validation_0-merror:0.276765	validation_0-mlogloss:0.863724
# [140]	validation_0-merror:0.276915	validation_0-mlogloss:0.863483
# [141]	validation_0-merror:0.276465	validation_0-mlogloss:0.863586
# [142]	validation_0-merror:0.276409	validation_0-mlogloss:0.863467
# [143]	validation_0-merror:0.276427	validation_0-mlogloss:0.863337
# [144]	validation_0-merror:0.275959	validation_0-mlogloss:0.862308
# [145]	validation_0-merror:0.276128	validation_0-mlogloss:0.862089
# [146]	validation_0-merror:0.275678	validation_0-mlogloss:0.861457
# [147]	validation_0-merror:0.275247	validation_0-mlogloss:0.860921
# [148]	validation_0-merror:0.274797	validation_0-mlogloss:0.86054
# [149]	validation_0-merror:0.275341	validation_0-mlogloss:0.861027
# [150]	validation_0-merror:0.275022	validation_0-mlogloss:0.861181
# [151]	validation_0-merror:0.274928	validation_0-mlogloss:0.861194
# [152]	validation_0-merror:0.27476	validation_0-mlogloss:0.861069
# [153]	validation_0-merror:0.274872	validation_0-mlogloss:0.861237
# [154]	validation_0-merror:0.274554	validation_0-mlogloss:0.861049
# [155]	validation_0-merror:0.274404	validation_0-mlogloss:0.860938
# [156]	validation_0-merror:0.274441	validation_0-mlogloss:0.860777
# [157]	validation_0-merror:0.274216	validation_0-mlogloss:0.860839
# [158]	validation_0-merror:0.273785	validation_0-mlogloss:0.859177
# [159]	validation_0-merror:0.27356	validation_0-mlogloss:0.858852
# [160]	validation_0-merror:0.273054	validation_0-mlogloss:0.858293
# [161]	validation_0-merror:0.272717	validation_0-mlogloss:0.858403
# [162]	validation_0-merror:0.272755	validation_0-mlogloss:0.858307
# [163]	validation_0-merror:0.272473	validation_0-mlogloss:0.857804
# [164]	validation_0-merror:0.271874	validation_0-mlogloss:0.85612
# [165]	validation_0-merror:0.271724	validation_0-mlogloss:0.855722
# [166]	validation_0-merror:0.271874	validation_0-mlogloss:0.855987
# [167]	validation_0-merror:0.271574	validation_0-mlogloss:0.855536
# [168]	validation_0-merror:0.27163	validation_0-mlogloss:0.855646
# [169]	validation_0-merror:0.271499	validation_0-mlogloss:0.855317
# [170]	validation_0-merror:0.271574	validation_0-mlogloss:0.85529
# [171]	validation_0-merror:0.271649	validation_0-mlogloss:0.855794
# [172]	validation_0-merror:0.27178	validation_0-mlogloss:0.856944
# [173]	validation_0-merror:0.271312	validation_0-mlogloss:0.856434
# [174]	validation_0-merror:0.27133	validation_0-mlogloss:0.856161
# [175]	validation_0-merror:0.271499	validation_0-mlogloss:0.856282
# [176]	validation_0-merror:0.271405	validation_0-mlogloss:0.855958
# [177]	validation_0-merror:0.271387	validation_0-mlogloss:0.85564
# [178]	validation_0-merror:0.271124	validation_0-mlogloss:0.855202
# [179]	validation_0-merror:0.270806	validation_0-mlogloss:0.854989
# [180]	validation_0-merror:0.271068	validation_0-mlogloss:0.855642
# [181]	validation_0-merror:0.270768	validation_0-mlogloss:0.854864
# [182]	validation_0-merror:0.270656	validation_0-mlogloss:0.855322
# [183]	validation_0-merror:0.270468	validation_0-mlogloss:0.855375
# [184]	validation_0-merror:0.270656	validation_0-mlogloss:0.854837
# [185]	validation_0-merror:0.270768	validation_0-mlogloss:0.855866
# [186]	validation_0-merror:0.270487	validation_0-mlogloss:0.856032
# [187]	validation_0-merror:0.270581	validation_0-mlogloss:0.855966
# [188]	validation_0-merror:0.270487	validation_0-mlogloss:0.856272
# [189]	validation_0-merror:0.270393	validation_0-mlogloss:0.856334
# [190]	validation_0-merror:0.270506	validation_0-mlogloss:0.856442
# [191]	validation_0-merror:0.270075	validation_0-mlogloss:0.855474
# [192]	validation_0-merror:0.269775	validation_0-mlogloss:0.855809
# [193]	validation_0-merror:0.269344	validation_0-mlogloss:0.854741
# [194]	validation_0-merror:0.268988	validation_0-mlogloss:0.854731
# [195]	validation_0-merror:0.269025	validation_0-mlogloss:0.854811
# [196]	validation_0-merror:0.268969	validation_0-mlogloss:0.854673
# [197]	validation_0-merror:0.2688	validation_0-mlogloss:0.854194
# [198]	validation_0-merror:0.268726	validation_0-mlogloss:0.854094
# [199]	validation_0-merror:0.268782	validation_0-mlogloss:0.854275
# [200]	validation_0-merror:0.268538	validation_0-mlogloss:0.854704
# [201]	validation_0-merror:0.268163	validation_0-mlogloss:0.854505
# [202]	validation_0-merror:0.268051	validation_0-mlogloss:0.855138
# [203]	validation_0-merror:0.268051	validation_0-mlogloss:0.855184
# [204]	validation_0-merror:0.26822	validation_0-mlogloss:0.855581
# [205]	validation_0-merror:0.268107	validation_0-mlogloss:0.85538
# [206]	validation_0-merror:0.26792	validation_0-mlogloss:0.855546
# [207]	validation_0-merror:0.267826	validation_0-mlogloss:0.855067
# [208]	validation_0-merror:0.267826	validation_0-mlogloss:0.855201
# [209]	validation_0-merror:0.267676	validation_0-mlogloss:0.855192
# [210]	validation_0-merror:0.267358	validation_0-mlogloss:0.854981
# [211]	validation_0-merror:0.267414	validation_0-mlogloss:0.855122
# [212]	validation_0-merror:0.267001	validation_0-mlogloss:0.854501
# [213]	validation_0-merror:0.266927	validation_0-mlogloss:0.854865
# [214]	validation_0-merror:0.267058	validation_0-mlogloss:0.855566
# [215]	validation_0-merror:0.266664	validation_0-mlogloss:0.855159
# [216]	validation_0-merror:0.266945	validation_0-mlogloss:0.855972
# [217]	validation_0-merror:0.26672	validation_0-mlogloss:0.855918
# [218]	validation_0-merror:0.266852	validation_0-mlogloss:0.856466
# [219]	validation_0-merror:0.266496	validation_0-mlogloss:0.85618
# [220]	validation_0-merror:0.266533	validation_0-mlogloss:0.856761
# [221]	validation_0-merror:0.266608	validation_0-mlogloss:0.856892
# [222]	validation_0-merror:0.266158	validation_0-mlogloss:0.856983
# [223]	validation_0-merror:0.266346	validation_0-mlogloss:0.856672
# [224]	validation_0-merror:0.266214	validation_0-mlogloss:0.856732
# [225]	validation_0-merror:0.265915	validation_0-mlogloss:0.856608
# [226]	validation_0-merror:0.265559	validation_0-mlogloss:0.856651
# [227]	validation_0-merror:0.265315	validation_0-mlogloss:0.856462
# [228]	validation_0-merror:0.265521	validation_0-mlogloss:0.85683
# [229]	validation_0-merror:0.265727	validation_0-mlogloss:0.857509
# [230]	validation_0-merror:0.265765	validation_0-mlogloss:0.858246
# [231]	validation_0-merror:0.265596	validation_0-mlogloss:0.858365
# [232]	validation_0-merror:0.265783	validation_0-mlogloss:0.858011
# [233]	validation_0-merror:0.26554	validation_0-mlogloss:0.857838
# [234]	validation_0-merror:0.265446	validation_0-mlogloss:0.857685
# [235]	validation_0-merror:0.26539	validation_0-mlogloss:0.858112
# [236]	validation_0-merror:0.265071	validation_0-mlogloss:0.858358
# [237]	validation_0-merror:0.264846	validation_0-mlogloss:0.858282
# [238]	validation_0-merror:0.26494	validation_0-mlogloss:0.858802
# [239]	validation_0-merror:0.264978	validation_0-mlogloss:0.859188
# [240]	validation_0-merror:0.264865	validation_0-mlogloss:0.85964
# [241]	validation_0-merror:0.264884	validation_0-mlogloss:0.859631
# [242]	validation_0-merror:0.264697	validation_0-mlogloss:0.859234
# [243]	validation_0-merror:0.264978	validation_0-mlogloss:0.859736
# [244]	validation_0-merror:0.264921	validation_0-mlogloss:0.859693
# [245]	validation_0-merror:0.264659	validation_0-mlogloss:0.859898
# [246]	validation_0-merror:0.26464	validation_0-mlogloss:0.860296
# [247]	validation_0-merror:0.264734	validation_0-mlogloss:0.861099
# [248]	validation_0-merror:0.26449	validation_0-mlogloss:0.861677
# Stopping. Best iteration:
# [198]	validation_0-merror:0.268726	validation_0-mlogloss:0.854094
#
# FITTING XGB ON BOOTSTRAP 1
#
#
# [0]	validation_0-merror:0.370519	validation_0-mlogloss:2.14603
# Multiple eval metrics have been passed: 'validation_0-mlogloss' will be used for early stopping.
#
# Will train until validation_0-mlogloss hasn't improved in 50 rounds.
# [1]	validation_0-merror:0.363548	validation_0-mlogloss:1.95822
# [2]	validation_0-merror:0.361374	validation_0-mlogloss:1.82697
# [3]	validation_0-merror:0.362086	validation_0-mlogloss:1.727
# [4]	validation_0-merror:0.362423	validation_0-mlogloss:1.64798
# [5]	validation_0-merror:0.359612	validation_0-mlogloss:1.58156
# [6]	validation_0-merror:0.357101	validation_0-mlogloss:1.52167
# [7]	validation_0-merror:0.357738	validation_0-mlogloss:1.47372
# [8]	validation_0-merror:0.357401	validation_0-mlogloss:1.43327
# [9]	validation_0-merror:0.355209	validation_0-mlogloss:1.39603
# [10]	validation_0-merror:0.355096	validation_0-mlogloss:1.36631
# [11]	validation_0-merror:0.353578	validation_0-mlogloss:1.3364
# [12]	validation_0-merror:0.352248	validation_0-mlogloss:1.30046
# [13]	validation_0-merror:0.351611	validation_0-mlogloss:1.27607
# [14]	validation_0-merror:0.349549	validation_0-mlogloss:1.25057
# [15]	validation_0-merror:0.347657	validation_0-mlogloss:1.22745
# [16]	validation_0-merror:0.347226	validation_0-mlogloss:1.20612
# [17]	validation_0-merror:0.346701	validation_0-mlogloss:1.19315
# [18]	validation_0-merror:0.345895	validation_0-mlogloss:1.17772
# [19]	validation_0-merror:0.344583	validation_0-mlogloss:1.16296
# [20]	validation_0-merror:0.342859	validation_0-mlogloss:1.14975
# [21]	validation_0-merror:0.342859	validation_0-mlogloss:1.13871
# [22]	validation_0-merror:0.342541	validation_0-mlogloss:1.12941
# [23]	validation_0-merror:0.341622	validation_0-mlogloss:1.11425
# [24]	validation_0-merror:0.340554	validation_0-mlogloss:1.10404
# [25]	validation_0-merror:0.340161	validation_0-mlogloss:1.09311
# [26]	validation_0-merror:0.339243	validation_0-mlogloss:1.08676
# [27]	validation_0-merror:0.33898	validation_0-mlogloss:1.08094
# [28]	validation_0-merror:0.33898	validation_0-mlogloss:1.07477
# [29]	validation_0-merror:0.337912	validation_0-mlogloss:1.06984
# [30]	validation_0-merror:0.33765	validation_0-mlogloss:1.06595
# [31]	validation_0-merror:0.337668	validation_0-mlogloss:1.06058
# [32]	validation_0-merror:0.336938	validation_0-mlogloss:1.05844
# [33]	validation_0-merror:0.336825	validation_0-mlogloss:1.05533
# [34]	validation_0-merror:0.336225	validation_0-mlogloss:1.05123
# [35]	validation_0-merror:0.336413	validation_0-mlogloss:1.0501
# [36]	validation_0-merror:0.336244	validation_0-mlogloss:1.04692
# [37]	validation_0-merror:0.336094	validation_0-mlogloss:1.0465
# [38]	validation_0-merror:0.335326	validation_0-mlogloss:1.03775
# [39]	validation_0-merror:0.333977	validation_0-mlogloss:1.03268
# [40]	validation_0-merror:0.334127	validation_0-mlogloss:1.02973
# [41]	validation_0-merror:0.333377	validation_0-mlogloss:1.02599
# [42]	validation_0-merror:0.332553	validation_0-mlogloss:1.0246
# [43]	validation_0-merror:0.33229	validation_0-mlogloss:1.02399
# [44]	validation_0-merror:0.330547	validation_0-mlogloss:1.0161
# [45]	validation_0-merror:0.329554	validation_0-mlogloss:1.01235
# [46]	validation_0-merror:0.329929	validation_0-mlogloss:1.01163
# [47]	validation_0-merror:0.329198	validation_0-mlogloss:1.00998
# [48]	validation_0-merror:0.327006	validation_0-mlogloss:1.00292
# [49]	validation_0-merror:0.326181	validation_0-mlogloss:1.00027
# [50]	validation_0-merror:0.326256	validation_0-mlogloss:0.998829
# [51]	validation_0-merror:0.324082	validation_0-mlogloss:0.992308
# [52]	validation_0-merror:0.323183	validation_0-mlogloss:0.987243
# [53]	validation_0-merror:0.322958	validation_0-mlogloss:0.985753
# [54]	validation_0-merror:0.321721	validation_0-mlogloss:0.983649
# [55]	validation_0-merror:0.320653	validation_0-mlogloss:0.979324
# [56]	validation_0-merror:0.318535	validation_0-mlogloss:0.973785
# [57]	validation_0-merror:0.318273	validation_0-mlogloss:0.973265
# [58]	validation_0-merror:0.317898	validation_0-mlogloss:0.970055
# [59]	validation_0-merror:0.316868	validation_0-mlogloss:0.966623
# [60]	validation_0-merror:0.316287	validation_0-mlogloss:0.966138
# [61]	validation_0-merror:0.316024	validation_0-mlogloss:0.963875
# [62]	validation_0-merror:0.315706	validation_0-mlogloss:0.961535
# [63]	validation_0-merror:0.31535	validation_0-mlogloss:0.960318
# [64]	validation_0-merror:0.315275	validation_0-mlogloss:0.960824
# [65]	validation_0-merror:0.312951	validation_0-mlogloss:0.956083
# [66]	validation_0-merror:0.311995	validation_0-mlogloss:0.952149
# [67]	validation_0-merror:0.311171	validation_0-mlogloss:0.951305
# [68]	validation_0-merror:0.310608	validation_0-mlogloss:0.948046
# [69]	validation_0-merror:0.310084	validation_0-mlogloss:0.947306
# [70]	validation_0-merror:0.309053	validation_0-mlogloss:0.944964
# [71]	validation_0-merror:0.308229	validation_0-mlogloss:0.942832
# [72]	validation_0-merror:0.307835	validation_0-mlogloss:0.942176
# [73]	validation_0-merror:0.306992	validation_0-mlogloss:0.93875
# [74]	validation_0-merror:0.306411	validation_0-mlogloss:0.937761
# [75]	validation_0-merror:0.306055	validation_0-mlogloss:0.936942
# [76]	validation_0-merror:0.305511	validation_0-mlogloss:0.935427
# [77]	validation_0-merror:0.304687	validation_0-mlogloss:0.934676
# [78]	validation_0-merror:0.304556	validation_0-mlogloss:0.933534
# [79]	validation_0-merror:0.304312	validation_0-mlogloss:0.932769
# [80]	validation_0-merror:0.302907	validation_0-mlogloss:0.929
# [81]	validation_0-merror:0.30285	validation_0-mlogloss:0.929468
# [82]	validation_0-merror:0.3027	validation_0-mlogloss:0.928768
# [83]	validation_0-merror:0.302719	validation_0-mlogloss:0.928482
# [84]	validation_0-merror:0.302251	validation_0-mlogloss:0.928177
# [85]	validation_0-merror:0.302607	validation_0-mlogloss:0.92847
# [86]	validation_0-merror:0.301895	validation_0-mlogloss:0.927099
# [87]	validation_0-merror:0.301782	validation_0-mlogloss:0.926575
# [88]	validation_0-merror:0.301314	validation_0-mlogloss:0.927136
# [89]	validation_0-merror:0.300958	validation_0-mlogloss:0.925794
# [90]	validation_0-merror:0.299946	validation_0-mlogloss:0.924398
# [91]	validation_0-merror:0.299927	validation_0-mlogloss:0.923648
# [92]	validation_0-merror:0.298746	validation_0-mlogloss:0.921174
# [93]	validation_0-merror:0.29824	validation_0-mlogloss:0.918342
# [94]	validation_0-merror:0.297922	validation_0-mlogloss:0.917841
# [95]	validation_0-merror:0.297697	validation_0-mlogloss:0.917198
# [96]	validation_0-merror:0.298072	validation_0-mlogloss:0.918018
# [97]	validation_0-merror:0.297191	validation_0-mlogloss:0.916012
# [98]	validation_0-merror:0.296985	validation_0-mlogloss:0.914924
# [99]	validation_0-merror:0.29586	validation_0-mlogloss:0.913696
# [100]	validation_0-merror:0.29528	validation_0-mlogloss:0.913638
# [101]	validation_0-merror:0.295073	validation_0-mlogloss:0.913565
# [102]	validation_0-merror:0.29483	validation_0-mlogloss:0.913997
# [103]	validation_0-merror:0.294399	validation_0-mlogloss:0.912447
# [104]	validation_0-merror:0.293705	validation_0-mlogloss:0.909942
# [105]	validation_0-merror:0.293387	validation_0-mlogloss:0.909766
# [106]	validation_0-merror:0.293274	validation_0-mlogloss:0.908793
# [107]	validation_0-merror:0.293143	validation_0-mlogloss:0.908212
# [108]	validation_0-merror:0.293274	validation_0-mlogloss:0.907297
# [109]	validation_0-merror:0.292825	validation_0-mlogloss:0.906743
# [110]	validation_0-merror:0.293181	validation_0-mlogloss:0.907082
# [111]	validation_0-merror:0.292693	validation_0-mlogloss:0.905936
# [112]	validation_0-merror:0.292375	validation_0-mlogloss:0.905223
# [113]	validation_0-merror:0.292019	validation_0-mlogloss:0.904036
# [114]	validation_0-merror:0.291756	validation_0-mlogloss:0.904511
# [115]	validation_0-merror:0.291775	validation_0-mlogloss:0.90351
# [116]	validation_0-merror:0.290932	validation_0-mlogloss:0.901212
# [117]	validation_0-merror:0.290801	validation_0-mlogloss:0.901066
# [118]	validation_0-merror:0.290857	validation_0-mlogloss:0.900809
# [119]	validation_0-merror:0.28992	validation_0-mlogloss:0.899006
# [120]	validation_0-merror:0.289658	validation_0-mlogloss:0.898908
# [121]	validation_0-merror:0.28902	validation_0-mlogloss:0.898217
# [122]	validation_0-merror:0.288533	validation_0-mlogloss:0.89666
# [123]	validation_0-merror:0.287896	validation_0-mlogloss:0.895193
# [124]	validation_0-merror:0.287615	validation_0-mlogloss:0.895131
# [125]	validation_0-merror:0.287465	validation_0-mlogloss:0.89468
# [126]	validation_0-merror:0.287184	validation_0-mlogloss:0.894214
# [127]	validation_0-merror:0.286978	validation_0-mlogloss:0.89349
# [128]	validation_0-merror:0.286884	validation_0-mlogloss:0.892395
# [129]	validation_0-merror:0.286247	validation_0-mlogloss:0.891444
# [130]	validation_0-merror:0.28591	validation_0-mlogloss:0.891933
# [131]	validation_0-merror:0.285666	validation_0-mlogloss:0.892449
# [132]	validation_0-merror:0.286116	validation_0-mlogloss:0.892493
# [133]	validation_0-merror:0.286097	validation_0-mlogloss:0.892917
# [134]	validation_0-merror:0.285779	validation_0-mlogloss:0.89198
# [135]	validation_0-merror:0.285685	validation_0-mlogloss:0.891408
# [136]	validation_0-merror:0.285928	validation_0-mlogloss:0.891473
# [137]	validation_0-merror:0.286191	validation_0-mlogloss:0.89154
# [138]	validation_0-merror:0.286097	validation_0-mlogloss:0.891661
# [139]	validation_0-merror:0.28546	validation_0-mlogloss:0.890719
# [140]	validation_0-merror:0.284898	validation_0-mlogloss:0.890023
# [141]	validation_0-merror:0.285291	validation_0-mlogloss:0.890067
# [142]	validation_0-merror:0.285273	validation_0-mlogloss:0.890691
# [143]	validation_0-merror:0.28546	validation_0-mlogloss:0.890364
# [144]	validation_0-merror:0.284804	validation_0-mlogloss:0.888313
# [145]	validation_0-merror:0.284523	validation_0-mlogloss:0.888163
# [146]	validation_0-merror:0.284767	validation_0-mlogloss:0.888352
# [147]	validation_0-merror:0.284223	validation_0-mlogloss:0.887645
# [148]	validation_0-merror:0.284017	validation_0-mlogloss:0.886549
# [149]	validation_0-merror:0.283998	validation_0-mlogloss:0.885853
# [150]	validation_0-merror:0.283549	validation_0-mlogloss:0.885006
# [151]	validation_0-merror:0.28338	validation_0-mlogloss:0.884923
# [152]	validation_0-merror:0.28323	validation_0-mlogloss:0.885462
# [153]	validation_0-merror:0.282986	validation_0-mlogloss:0.884912
# [154]	validation_0-merror:0.283005	validation_0-mlogloss:0.885274
# [155]	validation_0-merror:0.28308	validation_0-mlogloss:0.88579
# [156]	validation_0-merror:0.283024	validation_0-mlogloss:0.885408
# [157]	validation_0-merror:0.282705	validation_0-mlogloss:0.884909
# [158]	validation_0-merror:0.282705	validation_0-mlogloss:0.88477
# [159]	validation_0-merror:0.282499	validation_0-mlogloss:0.884082
# [160]	validation_0-merror:0.28233	validation_0-mlogloss:0.884283
# [161]	validation_0-merror:0.282106	validation_0-mlogloss:0.88451
# [162]	validation_0-merror:0.282218	validation_0-mlogloss:0.884611
# [163]	validation_0-merror:0.281993	validation_0-mlogloss:0.883795
# [164]	validation_0-merror:0.281731	validation_0-mlogloss:0.883161
# [165]	validation_0-merror:0.281225	validation_0-mlogloss:0.883261
# [166]	validation_0-merror:0.281656	validation_0-mlogloss:0.883371
# [167]	validation_0-merror:0.281393	validation_0-mlogloss:0.88276
# [168]	validation_0-merror:0.281019	validation_0-mlogloss:0.882456
# [169]	validation_0-merror:0.280531	validation_0-mlogloss:0.881881
# [170]	validation_0-merror:0.280813	validation_0-mlogloss:0.88181
# [171]	validation_0-merror:0.280531	validation_0-mlogloss:0.881005
# [172]	validation_0-merror:0.279932	validation_0-mlogloss:0.880684
# [173]	validation_0-merror:0.279763	validation_0-mlogloss:0.879634
# [174]	validation_0-merror:0.279707	validation_0-mlogloss:0.879933
# [175]	validation_0-merror:0.279276	validation_0-mlogloss:0.879206
# [176]	validation_0-merror:0.279014	validation_0-mlogloss:0.878963
# [177]	validation_0-merror:0.278976	validation_0-mlogloss:0.878211
# [178]	validation_0-merror:0.278995	validation_0-mlogloss:0.878184
# [179]	validation_0-merror:0.279276	validation_0-mlogloss:0.878417
# [180]	validation_0-merror:0.279088	validation_0-mlogloss:0.879281
# [181]	validation_0-merror:0.279107	validation_0-mlogloss:0.879335
# [182]	validation_0-merror:0.279088	validation_0-mlogloss:0.879448
# [183]	validation_0-merror:0.278901	validation_0-mlogloss:0.879451
# [184]	validation_0-merror:0.278826	validation_0-mlogloss:0.879469
# [185]	validation_0-merror:0.278882	validation_0-mlogloss:0.879792
# [186]	validation_0-merror:0.278882	validation_0-mlogloss:0.88041
# [187]	validation_0-merror:0.278526	validation_0-mlogloss:0.879549
# [188]	validation_0-merror:0.278226	validation_0-mlogloss:0.880237
# [189]	validation_0-merror:0.278601	validation_0-mlogloss:0.880722
# [190]	validation_0-merror:0.278451	validation_0-mlogloss:0.881024
# [191]	validation_0-merror:0.278376	validation_0-mlogloss:0.881743
# [192]	validation_0-merror:0.278002	validation_0-mlogloss:0.880494
# [193]	validation_0-merror:0.277983	validation_0-mlogloss:0.880452
# [194]	validation_0-merror:0.278039	validation_0-mlogloss:0.881002
# [195]	validation_0-merror:0.27832	validation_0-mlogloss:0.880954
# [196]	validation_0-merror:0.277927	validation_0-mlogloss:0.88045
# [197]	validation_0-merror:0.277908	validation_0-mlogloss:0.880334
# [198]	validation_0-merror:0.27802	validation_0-mlogloss:0.880452
# [199]	validation_0-merror:0.277458	validation_0-mlogloss:0.879898
# [200]	validation_0-merror:0.277383	validation_0-mlogloss:0.879513
# [201]	validation_0-merror:0.27714	validation_0-mlogloss:0.879498
# [202]	validation_0-merror:0.276577	validation_0-mlogloss:0.878139
# [203]	validation_0-merror:0.27669	validation_0-mlogloss:0.878803
# [204]	validation_0-merror:0.276409	validation_0-mlogloss:0.87886
# [205]	validation_0-merror:0.276465	validation_0-mlogloss:0.879592
# [206]	validation_0-merror:0.276334	validation_0-mlogloss:0.879859
# [207]	validation_0-merror:0.276259	validation_0-mlogloss:0.880202
# [208]	validation_0-merror:0.276053	validation_0-mlogloss:0.879866
# [209]	validation_0-merror:0.275903	validation_0-mlogloss:0.880072
# [210]	validation_0-merror:0.275528	validation_0-mlogloss:0.879999
# [211]	validation_0-merror:0.275922	validation_0-mlogloss:0.881054
# [212]	validation_0-merror:0.27594	validation_0-mlogloss:0.881758
# [213]	validation_0-merror:0.275996	validation_0-mlogloss:0.882196
# [214]	validation_0-merror:0.275959	validation_0-mlogloss:0.882707
# [215]	validation_0-merror:0.27579	validation_0-mlogloss:0.883309
# [216]	validation_0-merror:0.275734	validation_0-mlogloss:0.883597
# [217]	validation_0-merror:0.275753	validation_0-mlogloss:0.883344
# [218]	validation_0-merror:0.275978	validation_0-mlogloss:0.883997
# [219]	validation_0-merror:0.27579	validation_0-mlogloss:0.88383
# [220]	validation_0-merror:0.275697	validation_0-mlogloss:0.883934
# [221]	validation_0-merror:0.275528	validation_0-mlogloss:0.884294
# [222]	validation_0-merror:0.275565	validation_0-mlogloss:0.883979
# [223]	validation_0-merror:0.275303	validation_0-mlogloss:0.883805
# [224]	validation_0-merror:0.275247	validation_0-mlogloss:0.883995
# [225]	validation_0-merror:0.274966	validation_0-mlogloss:0.883987
# [226]	validation_0-merror:0.275134	validation_0-mlogloss:0.884365
# [227]	validation_0-merror:0.275097	validation_0-mlogloss:0.884701
# [228]	validation_0-merror:0.274947	validation_0-mlogloss:0.884764
# [229]	validation_0-merror:0.274591	validation_0-mlogloss:0.884438
# [230]	validation_0-merror:0.274591	validation_0-mlogloss:0.884923
# [231]	validation_0-merror:0.274741	validation_0-mlogloss:0.885584
# [232]	validation_0-merror:0.274722	validation_0-mlogloss:0.885971
# [233]	validation_0-merror:0.274685	validation_0-mlogloss:0.886559
# [234]	validation_0-merror:0.274816	validation_0-mlogloss:0.886736
# [235]	validation_0-merror:0.274853	validation_0-mlogloss:0.887083
# [236]	validation_0-merror:0.274685	validation_0-mlogloss:0.887661
# [237]	validation_0-merror:0.27446	validation_0-mlogloss:0.887949
# [238]	validation_0-merror:0.274385	validation_0-mlogloss:0.888078
# [239]	validation_0-merror:0.274291	validation_0-mlogloss:0.887884
# [240]	validation_0-merror:0.274254	validation_0-mlogloss:0.887881
# [241]	validation_0-merror:0.274441	validation_0-mlogloss:0.88838
# [242]	validation_0-merror:0.274647	validation_0-mlogloss:0.888406
# [243]	validation_0-merror:0.274254	validation_0-mlogloss:0.887714
# [244]	validation_0-merror:0.27416	validation_0-mlogloss:0.887473
# [245]	validation_0-merror:0.273973	validation_0-mlogloss:0.887569
# [246]	validation_0-merror:0.273841	validation_0-mlogloss:0.887843
# [247]	validation_0-merror:0.273579	validation_0-mlogloss:0.887646
# [248]	validation_0-merror:0.273317	validation_0-mlogloss:0.887445
# [249]	validation_0-merror:0.273504	validation_0-mlogloss:0.887996
# [250]	validation_0-merror:0.273598	validation_0-mlogloss:0.888294
# [251]	validation_0-merror:0.273504	validation_0-mlogloss:0.888972
# [252]	validation_0-merror:0.27356	validation_0-mlogloss:0.889814
# Stopping. Best iteration:
# [202]	validation_0-merror:0.276577	validation_0-mlogloss:0.878139
#
# FITTING XGB ON BOOTSTRAP 2
#
#
# [0]	validation_0-merror:0.367352	validation_0-mlogloss:2.14405
# Multiple eval metrics have been passed: 'validation_0-mlogloss' will be used for early stopping.
#
# Will train until validation_0-mlogloss hasn't improved in 50 rounds.
# [1]	validation_0-merror:0.362236	validation_0-mlogloss:1.95426
# [2]	validation_0-merror:0.360812	validation_0-mlogloss:1.82201
# [3]	validation_0-merror:0.359781	validation_0-mlogloss:1.72003
# [4]	validation_0-merror:0.352473	validation_0-mlogloss:1.62997
# [5]	validation_0-merror:0.348387	validation_0-mlogloss:1.55861
# [6]	validation_0-merror:0.347788	validation_0-mlogloss:1.49989
# [7]	validation_0-merror:0.349399	validation_0-mlogloss:1.45373
# [8]	validation_0-merror:0.347113	validation_0-mlogloss:1.40785
# [9]	validation_0-merror:0.34567	validation_0-mlogloss:1.36755
# [10]	validation_0-merror:0.34522	validation_0-mlogloss:1.33512
# [11]	validation_0-merror:0.343234	validation_0-mlogloss:1.30509
# [12]	validation_0-merror:0.343553	validation_0-mlogloss:1.27824
# [13]	validation_0-merror:0.342878	validation_0-mlogloss:1.25508
# [14]	validation_0-merror:0.343403	validation_0-mlogloss:1.23504
# [15]	validation_0-merror:0.341735	validation_0-mlogloss:1.21553
# [16]	validation_0-merror:0.340123	validation_0-mlogloss:1.19769
# [17]	validation_0-merror:0.340742	validation_0-mlogloss:1.18562
# [18]	validation_0-merror:0.339224	validation_0-mlogloss:1.17194
# [19]	validation_0-merror:0.339224	validation_0-mlogloss:1.16147
# [20]	validation_0-merror:0.338849	validation_0-mlogloss:1.15368
# [21]	validation_0-merror:0.338399	validation_0-mlogloss:1.14295
# [22]	validation_0-merror:0.335982	validation_0-mlogloss:1.12963
# [23]	validation_0-merror:0.336019	validation_0-mlogloss:1.12225
# [24]	validation_0-merror:0.335288	validation_0-mlogloss:1.11432
# [25]	validation_0-merror:0.335907	validation_0-mlogloss:1.10876
# [26]	validation_0-merror:0.333808	validation_0-mlogloss:1.09911
# [27]	validation_0-merror:0.333321	validation_0-mlogloss:1.09478
# [28]	validation_0-merror:0.333096	validation_0-mlogloss:1.08677
# [29]	validation_0-merror:0.333621	validation_0-mlogloss:1.08373
# [30]	validation_0-merror:0.332253	validation_0-mlogloss:1.07741
# [31]	validation_0-merror:0.331616	validation_0-mlogloss:1.07059
# [32]	validation_0-merror:0.331953	validation_0-mlogloss:1.06908
# [33]	validation_0-merror:0.330997	validation_0-mlogloss:1.06361
# [34]	validation_0-merror:0.330191	validation_0-mlogloss:1.05985
# [35]	validation_0-merror:0.328617	validation_0-mlogloss:1.05103
# [36]	validation_0-merror:0.328524	validation_0-mlogloss:1.05118
# [37]	validation_0-merror:0.327587	validation_0-mlogloss:1.04632
# [38]	validation_0-merror:0.327924	validation_0-mlogloss:1.04447
# [39]	validation_0-merror:0.327587	validation_0-mlogloss:1.03986
# [40]	validation_0-merror:0.326893	validation_0-mlogloss:1.0371
# [41]	validation_0-merror:0.325937	validation_0-mlogloss:1.03031
# [42]	validation_0-merror:0.324851	validation_0-mlogloss:1.02526
# [43]	validation_0-merror:0.324644	validation_0-mlogloss:1.02193
# [44]	validation_0-merror:0.322958	validation_0-mlogloss:1.01553
# [45]	validation_0-merror:0.322939	validation_0-mlogloss:1.01379
# [46]	validation_0-merror:0.322377	validation_0-mlogloss:1.01186
# [47]	validation_0-merror:0.322321	validation_0-mlogloss:1.01081
# [48]	validation_0-merror:0.32159	validation_0-mlogloss:1.00829
# [49]	validation_0-merror:0.320072	validation_0-mlogloss:1.00382
# [50]	validation_0-merror:0.318442	validation_0-mlogloss:0.999028
# [51]	validation_0-merror:0.318161	validation_0-mlogloss:0.996685
# [52]	validation_0-merror:0.317542	validation_0-mlogloss:0.992395
# [53]	validation_0-merror:0.316324	validation_0-mlogloss:0.988173
# [54]	validation_0-merror:0.315893	validation_0-mlogloss:0.986195
# [55]	validation_0-merror:0.315331	validation_0-mlogloss:0.98265
# [56]	validation_0-merror:0.314488	validation_0-mlogloss:0.98066
# [57]	validation_0-merror:0.313382	validation_0-mlogloss:0.97682
# [58]	validation_0-merror:0.313626	validation_0-mlogloss:0.977175
# [59]	validation_0-merror:0.313569	validation_0-mlogloss:0.977293
# [60]	validation_0-merror:0.311976	validation_0-mlogloss:0.97201
# [61]	validation_0-merror:0.310946	validation_0-mlogloss:0.967569
# [62]	validation_0-merror:0.310871	validation_0-mlogloss:0.96737
# [63]	validation_0-merror:0.310309	validation_0-mlogloss:0.966736
# [64]	validation_0-merror:0.309334	validation_0-mlogloss:0.964707
# [65]	validation_0-merror:0.309109	validation_0-mlogloss:0.96352
# [66]	validation_0-merror:0.308903	validation_0-mlogloss:0.962896
# [67]	validation_0-merror:0.307704	validation_0-mlogloss:0.958741
# [68]	validation_0-merror:0.307085	validation_0-mlogloss:0.957541
# [69]	validation_0-merror:0.307273	validation_0-mlogloss:0.958064
# [70]	validation_0-merror:0.30716	validation_0-mlogloss:0.956787
# [71]	validation_0-merror:0.306936	validation_0-mlogloss:0.956138
# [72]	validation_0-merror:0.305755	validation_0-mlogloss:0.952899
# [73]	validation_0-merror:0.30568	validation_0-mlogloss:0.951838
# [74]	validation_0-merror:0.305249	validation_0-mlogloss:0.950822
# [75]	validation_0-merror:0.304724	validation_0-mlogloss:0.948857
# [76]	validation_0-merror:0.304106	validation_0-mlogloss:0.947156
# [77]	validation_0-merror:0.303469	validation_0-mlogloss:0.945369
# [78]	validation_0-merror:0.3036	validation_0-mlogloss:0.946572
# [79]	validation_0-merror:0.3039	validation_0-mlogloss:0.947016
# [80]	validation_0-merror:0.302944	validation_0-mlogloss:0.944156
# [81]	validation_0-merror:0.302288	validation_0-mlogloss:0.942116
# [82]	validation_0-merror:0.30167	validation_0-mlogloss:0.940787
# [83]	validation_0-merror:0.30047	validation_0-mlogloss:0.938446
# [84]	validation_0-merror:0.300508	validation_0-mlogloss:0.938139
# [85]	validation_0-merror:0.300808	validation_0-mlogloss:0.939342
# [86]	validation_0-merror:0.300189	validation_0-mlogloss:0.937009
# [87]	validation_0-merror:0.299702	validation_0-mlogloss:0.936874
# [88]	validation_0-merror:0.299477	validation_0-mlogloss:0.936184
# [89]	validation_0-merror:0.299571	validation_0-mlogloss:0.93597
# [90]	validation_0-merror:0.298971	validation_0-mlogloss:0.934468
# [91]	validation_0-merror:0.29854	validation_0-mlogloss:0.932238
# [92]	validation_0-merror:0.298278	validation_0-mlogloss:0.932273
# [93]	validation_0-merror:0.297847	validation_0-mlogloss:0.932123
# [94]	validation_0-merror:0.298297	validation_0-mlogloss:0.932654
# [95]	validation_0-merror:0.297697	validation_0-mlogloss:0.931284
# [96]	validation_0-merror:0.297004	validation_0-mlogloss:0.929146
# [97]	validation_0-merror:0.296067	validation_0-mlogloss:0.927285
# [98]	validation_0-merror:0.296142	validation_0-mlogloss:0.926943
# [99]	validation_0-merror:0.296291	validation_0-mlogloss:0.926856
# [100]	validation_0-merror:0.296123	validation_0-mlogloss:0.925561
# [101]	validation_0-merror:0.29586	validation_0-mlogloss:0.925937
# [102]	validation_0-merror:0.295017	validation_0-mlogloss:0.924902
# [103]	validation_0-merror:0.294867	validation_0-mlogloss:0.924077
# [104]	validation_0-merror:0.294774	validation_0-mlogloss:0.923609
# [105]	validation_0-merror:0.294661	validation_0-mlogloss:0.92323
# [106]	validation_0-merror:0.294324	validation_0-mlogloss:0.922156
# [107]	validation_0-merror:0.29393	validation_0-mlogloss:0.921997
# [108]	validation_0-merror:0.293893	validation_0-mlogloss:0.922229
# [109]	validation_0-merror:0.293705	validation_0-mlogloss:0.922253
# [110]	validation_0-merror:0.293687	validation_0-mlogloss:0.922702
# [111]	validation_0-merror:0.293424	validation_0-mlogloss:0.921359
# [112]	validation_0-merror:0.292937	validation_0-mlogloss:0.920161
# [113]	validation_0-merror:0.292618	validation_0-mlogloss:0.920252
# [114]	validation_0-merror:0.291794	validation_0-mlogloss:0.917383
# [115]	validation_0-merror:0.291663	validation_0-mlogloss:0.917481
# [116]	validation_0-merror:0.290951	validation_0-mlogloss:0.91636
# [117]	validation_0-merror:0.290951	validation_0-mlogloss:0.915975
# [118]	validation_0-merror:0.290951	validation_0-mlogloss:0.915274
# [119]	validation_0-merror:0.290745	validation_0-mlogloss:0.915383
# [120]	validation_0-merror:0.29067	validation_0-mlogloss:0.915698
# [121]	validation_0-merror:0.290426	validation_0-mlogloss:0.914964
# [122]	validation_0-merror:0.29037	validation_0-mlogloss:0.915323
# [123]	validation_0-merror:0.289826	validation_0-mlogloss:0.914842
# [124]	validation_0-merror:0.289302	validation_0-mlogloss:0.913822
# [125]	validation_0-merror:0.288702	validation_0-mlogloss:0.912339
# [126]	validation_0-merror:0.288402	validation_0-mlogloss:0.911347
# [127]	validation_0-merror:0.288158	validation_0-mlogloss:0.910706
# [128]	validation_0-merror:0.288046	validation_0-mlogloss:0.90976
# [129]	validation_0-merror:0.287371	validation_0-mlogloss:0.910079
# [130]	validation_0-merror:0.287428	validation_0-mlogloss:0.910611
# [131]	validation_0-merror:0.28739	validation_0-mlogloss:0.91007
# [132]	validation_0-merror:0.287165	validation_0-mlogloss:0.909552
# [133]	validation_0-merror:0.287446	validation_0-mlogloss:0.910019
# [134]	validation_0-merror:0.287428	validation_0-mlogloss:0.910053
# [135]	validation_0-merror:0.287072	validation_0-mlogloss:0.908501
# [136]	validation_0-merror:0.287147	validation_0-mlogloss:0.908742
# [137]	validation_0-merror:0.286978	validation_0-mlogloss:0.908791
# [138]	validation_0-merror:0.286622	validation_0-mlogloss:0.909041
# [139]	validation_0-merror:0.286303	validation_0-mlogloss:0.90798
# [140]	validation_0-merror:0.286528	validation_0-mlogloss:0.908537
# [141]	validation_0-merror:0.28621	validation_0-mlogloss:0.907838
# [142]	validation_0-merror:0.28576	validation_0-mlogloss:0.905919
# [143]	validation_0-merror:0.285497	validation_0-mlogloss:0.904037
# [144]	validation_0-merror:0.284542	validation_0-mlogloss:0.902526
# [145]	validation_0-merror:0.284467	validation_0-mlogloss:0.903267
# [146]	validation_0-merror:0.284767	validation_0-mlogloss:0.9034
# [147]	validation_0-merror:0.284486	validation_0-mlogloss:0.903111
# [148]	validation_0-merror:0.284129	validation_0-mlogloss:0.903214
# [149]	validation_0-merror:0.283661	validation_0-mlogloss:0.90211
# [150]	validation_0-merror:0.283867	validation_0-mlogloss:0.901517
# [151]	validation_0-merror:0.283755	validation_0-mlogloss:0.901633
# [152]	validation_0-merror:0.28368	validation_0-mlogloss:0.901734
# [153]	validation_0-merror:0.283099	validation_0-mlogloss:0.900785
# [154]	validation_0-merror:0.282818	validation_0-mlogloss:0.8999
# [155]	validation_0-merror:0.283324	validation_0-mlogloss:0.900096
# [156]	validation_0-merror:0.283267	validation_0-mlogloss:0.900305
# [157]	validation_0-merror:0.283043	validation_0-mlogloss:0.899832
# [158]	validation_0-merror:0.283211	validation_0-mlogloss:0.900309
# [159]	validation_0-merror:0.282668	validation_0-mlogloss:0.899445
# [160]	validation_0-merror:0.282986	validation_0-mlogloss:0.899504
# [161]	validation_0-merror:0.282836	validation_0-mlogloss:0.899252
# [162]	validation_0-merror:0.282443	validation_0-mlogloss:0.898942
# [163]	validation_0-merror:0.282555	validation_0-mlogloss:0.899118
# [164]	validation_0-merror:0.282761	validation_0-mlogloss:0.899238
# [165]	validation_0-merror:0.282387	validation_0-mlogloss:0.898772
# [166]	validation_0-merror:0.282462	validation_0-mlogloss:0.899431
# [167]	validation_0-merror:0.281937	validation_0-mlogloss:0.898783
# [168]	validation_0-merror:0.281918	validation_0-mlogloss:0.898993
# [169]	validation_0-merror:0.281562	validation_0-mlogloss:0.898641
# [170]	validation_0-merror:0.281562	validation_0-mlogloss:0.898833
# [171]	validation_0-merror:0.281618	validation_0-mlogloss:0.89922
# [172]	validation_0-merror:0.281675	validation_0-mlogloss:0.899196
# [173]	validation_0-merror:0.281562	validation_0-mlogloss:0.898875
# [174]	validation_0-merror:0.28145	validation_0-mlogloss:0.898857
# [175]	validation_0-merror:0.281712	validation_0-mlogloss:0.89919
# [176]	validation_0-merror:0.281262	validation_0-mlogloss:0.897485
# [177]	validation_0-merror:0.281618	validation_0-mlogloss:0.898345
# [178]	validation_0-merror:0.281543	validation_0-mlogloss:0.898256
# [179]	validation_0-merror:0.281675	validation_0-mlogloss:0.898397
# [180]	validation_0-merror:0.281262	validation_0-mlogloss:0.898381
# [181]	validation_0-merror:0.28115	validation_0-mlogloss:0.897503
# [182]	validation_0-merror:0.280775	validation_0-mlogloss:0.897294
# [183]	validation_0-merror:0.28055	validation_0-mlogloss:0.896995
# [184]	validation_0-merror:0.280475	validation_0-mlogloss:0.896953
# [185]	validation_0-merror:0.280644	validation_0-mlogloss:0.897343
# [186]	validation_0-merror:0.280288	validation_0-mlogloss:0.896894
# [187]	validation_0-merror:0.279932	validation_0-mlogloss:0.897482
# [188]	validation_0-merror:0.280138	validation_0-mlogloss:0.897916
# [189]	validation_0-merror:0.279482	validation_0-mlogloss:0.896702
# [190]	validation_0-merror:0.279594	validation_0-mlogloss:0.897734
# [191]	validation_0-merror:0.279594	validation_0-mlogloss:0.898207
# [192]	validation_0-merror:0.279857	validation_0-mlogloss:0.898391
# [193]	validation_0-merror:0.279576	validation_0-mlogloss:0.89901
# [194]	validation_0-merror:0.279538	validation_0-mlogloss:0.899539
# [195]	validation_0-merror:0.27937	validation_0-mlogloss:0.899317
# [196]	validation_0-merror:0.279276	validation_0-mlogloss:0.899026
# [197]	validation_0-merror:0.279538	validation_0-mlogloss:0.89927
# [198]	validation_0-merror:0.279707	validation_0-mlogloss:0.89981
# [199]	validation_0-merror:0.27922	validation_0-mlogloss:0.899753
# [200]	validation_0-merror:0.279014	validation_0-mlogloss:0.899082
# [201]	validation_0-merror:0.279163	validation_0-mlogloss:0.899251
# [202]	validation_0-merror:0.279163	validation_0-mlogloss:0.899563
# [203]	validation_0-merror:0.27907	validation_0-mlogloss:0.899575
# [204]	validation_0-merror:0.279088	validation_0-mlogloss:0.900721
# [205]	validation_0-merror:0.278901	validation_0-mlogloss:0.90059
# [206]	validation_0-merror:0.278807	validation_0-mlogloss:0.900718
# [207]	validation_0-merror:0.278545	validation_0-mlogloss:0.900655
# [208]	validation_0-merror:0.278583	validation_0-mlogloss:0.901299
# [209]	validation_0-merror:0.278976	validation_0-mlogloss:0.901801
# [210]	validation_0-merror:0.278732	validation_0-mlogloss:0.901816
# [211]	validation_0-merror:0.278601	validation_0-mlogloss:0.901876
# [212]	validation_0-merror:0.278283	validation_0-mlogloss:0.901776
# [213]	validation_0-merror:0.278058	validation_0-mlogloss:0.901325
# [214]	validation_0-merror:0.277889	validation_0-mlogloss:0.901638
# [215]	validation_0-merror:0.277608	validation_0-mlogloss:0.901737
# [216]	validation_0-merror:0.277945	validation_0-mlogloss:0.902172
# [217]	validation_0-merror:0.277814	validation_0-mlogloss:0.902195
# [218]	validation_0-merror:0.27787	validation_0-mlogloss:0.902342
# [219]	validation_0-merror:0.277758	validation_0-mlogloss:0.902599
# [220]	validation_0-merror:0.277889	validation_0-mlogloss:0.902644
# [221]	validation_0-merror:0.277571	validation_0-mlogloss:0.902483
# ...
# Epoch 28/500
# 49988/49988 - 5s - loss: 2.0097 - sparse_categorical_accuracy: 0.4624 - sparse_top_k_categorical_accuracy: 0.8325 - val_loss: 2.4236 - val_sparse_categorical_accuracy: 0.4618 - val_sparse_top_k_categorical_accuracy: 0.6823
# Epoch 29/500
# 49988/49988 - 5s - loss: 2.0343 - sparse_categorical_accuracy: 0.4628 - sparse_top_k_categorical_accuracy: 0.8332 - val_loss: 1.6072 - val_sparse_categorical_accuracy: 0.6192 - val_sparse_top_k_categorical_accuracy: 0.7504
# Epoch 30/500
# 49988/49988 - 5s - loss: 2.0138 - sparse_categorical_accuracy: 0.4632 - sparse_top_k_categorical_accuracy: 0.8326 - val_loss: 1.7039 - val_sparse_categorical_accuracy: 0.6178 - val_sparse_top_k_categorical_accuracy: 0.7729
# Epoch 31/500
# 49988/49988 - 5s - loss: 1.9902 - sparse_categorical_accuracy: 0.4653 - sparse_top_k_categorical_accuracy: 0.8358 - val_loss: 1.6755 - val_sparse_categorical_accuracy: 0.6987 - val_sparse_top_k_categorical_accuracy: 0.8163
# Epoch 32/500
# 49988/49988 - 5s - loss: 1.9855 - sparse_categorical_accuracy: 0.4688 - sparse_top_k_categorical_accuracy: 0.8358 - val_loss: 1.7197 - val_sparse_categorical_accuracy: 0.6128 - val_sparse_top_k_categorical_accuracy: 0.7595
# Epoch 33/500
# 49988/49988 - 5s - loss: 2.0172 - sparse_categorical_accuracy: 0.4655 - sparse_top_k_categorical_accuracy: 0.8349 - val_loss: 2.1960 - val_sparse_categorical_accuracy: 0.6152 - val_sparse_top_k_categorical_accuracy: 0.7891
# Epoch 34/500
# 49988/49988 - 5s - loss: 1.9814 - sparse_categorical_accuracy: 0.4685 - sparse_top_k_categorical_accuracy: 0.8360 - val_loss: 1.7295 - val_sparse_categorical_accuracy: 0.6008 - val_sparse_top_k_categorical_accuracy: 0.7594
# Epoch 35/500
# 49988/49988 - 5s - loss: 1.9813 - sparse_categorical_accuracy: 0.4672 - sparse_top_k_categorical_accuracy: 0.8355 - val_loss: 1.5720 - val_sparse_categorical_accuracy: 0.6370 - val_sparse_top_k_categorical_accuracy: 0.7511
# Epoch 36/500
# 49988/49988 - 5s - loss: 2.0067 - sparse_categorical_accuracy: 0.4659 - sparse_top_k_categorical_accuracy: 0.8348 - val_loss: 1.6631 - val_sparse_categorical_accuracy: 0.6500 - val_sparse_top_k_categorical_accuracy: 0.7742
# Epoch 37/500
# 49988/49988 - 5s - loss: 1.9634 - sparse_categorical_accuracy: 0.4689 - sparse_top_k_categorical_accuracy: 0.8371 - val_loss: 1.4973 - val_sparse_categorical_accuracy: 0.6497 - val_sparse_top_k_categorical_accuracy: 0.7968
# Epoch 38/500
# 49988/49988 - 5s - loss: 1.9516 - sparse_categorical_accuracy: 0.4690 - sparse_top_k_categorical_accuracy: 0.8372 - val_loss: 1.6216 - val_sparse_categorical_accuracy: 0.6332 - val_sparse_top_k_categorical_accuracy: 0.7948
# Epoch 39/500
# 49988/49988 - 5s - loss: 1.9390 - sparse_categorical_accuracy: 0.4709 - sparse_top_k_categorical_accuracy: 0.8368 - val_loss: 1.5294 - val_sparse_categorical_accuracy: 0.6246 - val_sparse_top_k_categorical_accuracy: 0.7789
# Epoch 40/500
# 49988/49988 - 5s - loss: 1.9735 - sparse_categorical_accuracy: 0.4707 - sparse_top_k_categorical_accuracy: 0.8357 - val_loss: 1.5256 - val_sparse_categorical_accuracy: 0.6629 - val_sparse_top_k_categorical_accuracy: 0.7862
# Epoch 41/500
# 49988/49988 - 5s - loss: 2.0007 - sparse_categorical_accuracy: 0.4693 - sparse_top_k_categorical_accuracy: 0.8341 - val_loss: 1.5457 - val_sparse_categorical_accuracy: 0.6702 - val_sparse_top_k_categorical_accuracy: 0.8151
# Epoch 42/500
# 49988/49988 - 5s - loss: 1.9295 - sparse_categorical_accuracy: 0.4732 - sparse_top_k_categorical_accuracy: 0.8383 - val_loss: 1.4125 - val_sparse_categorical_accuracy: 0.7009 - val_sparse_top_k_categorical_accuracy: 0.8131
# Epoch 43/500
# 49988/49988 - 5s - loss: 1.9265 - sparse_categorical_accuracy: 0.4742 - sparse_top_k_categorical_accuracy: 0.8364 - val_loss: 1.5216 - val_sparse_categorical_accuracy: 0.6497 - val_sparse_top_k_categorical_accuracy: 0.8091
# Epoch 44/500
# 49988/49988 - 5s - loss: 1.9163 - sparse_categorical_accuracy: 0.4749 - sparse_top_k_categorical_accuracy: 0.8382 - val_loss: 1.5799 - val_sparse_categorical_accuracy: 0.6478 - val_sparse_top_k_categorical_accuracy: 0.8095
# Epoch 45/500
# 49988/49988 - 5s - loss: 1.9324 - sparse_categorical_accuracy: 0.4754 - sparse_top_k_categorical_accuracy: 0.8378 - val_loss: 1.5628 - val_sparse_categorical_accuracy: 0.6729 - val_sparse_top_k_categorical_accuracy: 0.8046
# Epoch 46/500
# 49988/49988 - 5s - loss: 1.9785 - sparse_categorical_accuracy: 0.4705 - sparse_top_k_categorical_accuracy: 0.8373 - val_loss: 2.8627 - val_sparse_categorical_accuracy: 0.4284 - val_sparse_top_k_categorical_accuracy: 0.6771
# Epoch 47/500
# 49988/49988 - 5s - loss: 1.9459 - sparse_categorical_accuracy: 0.4736 - sparse_top_k_categorical_accuracy: 0.8391 - val_loss: 2.6236 - val_sparse_categorical_accuracy: 0.5135 - val_sparse_top_k_categorical_accuracy: 0.7177
# Epoch 48/500
# 49988/49988 - 5s - loss: 2.0074 - sparse_categorical_accuracy: 0.4660 - sparse_top_k_categorical_accuracy: 0.8333 - val_loss: 2.1932 - val_sparse_categorical_accuracy: 0.5812 - val_sparse_top_k_categorical_accuracy: 0.7414
# Epoch 49/500
# 49988/49988 - 5s - loss: 1.9560 - sparse_categorical_accuracy: 0.4735 - sparse_top_k_categorical_accuracy: 0.8370 - val_loss: 1.6349 - val_sparse_categorical_accuracy: 0.5936 - val_sparse_top_k_categorical_accuracy: 0.8118
# Epoch 50/500
# 49988/49988 - 5s - loss: 1.9000 - sparse_categorical_accuracy: 0.4735 - sparse_top_k_categorical_accuracy: 0.8385 - val_loss: 1.4428 - val_sparse_categorical_accuracy: 0.6597 - val_sparse_top_k_categorical_accuracy: 0.8080
# Epoch 51/500
# 49988/49988 - 5s - loss: 1.8977 - sparse_categorical_accuracy: 0.4731 - sparse_top_k_categorical_accuracy: 0.8396 - val_loss: 1.4618 - val_sparse_categorical_accuracy: 0.6769 - val_sparse_top_k_categorical_accuracy: 0.8183
# Epoch 52/500
# Restoring model weights from the end of the best epoch.
# 49988/49988 - 5s - loss: 1.9341 - sparse_categorical_accuracy: 0.4719 - sparse_top_k_categorical_accuracy: 0.8373 - val_loss: 1.7582 - val_sparse_categorical_accuracy: 0.6974 - val_sparse_top_k_categorical_accuracy: 0.8348
# Epoch 00052: early stopping
# FITTING NN ON BOOTSTRAP 3
#
#
# Train on 49988 samples, validate on 53363 samples
# Epoch 1/500
# 49988/49988 - 6s - loss: 19.9427 - sparse_categorical_accuracy: 0.3805 - sparse_top_k_categorical_accuracy: 0.7509 - val_loss: 2.2362 - val_sparse_categorical_accuracy: 0.5993 - val_sparse_top_k_categorical_accuracy: 0.7967
# Epoch 2/500
# 49988/49988 - 5s - loss: 2.5781 - sparse_categorical_accuracy: 0.4187 - sparse_top_k_categorical_accuracy: 0.7957 - val_loss: 1.9103 - val_sparse_categorical_accuracy: 0.6099 - val_sparse_top_k_categorical_accuracy: 0.7630
# Epoch 3/500
# 49988/49988 - 5s - loss: 2.3602 - sparse_categorical_accuracy: 0.4330 - sparse_top_k_categorical_accuracy: 0.8073 - val_loss: 1.9710 - val_sparse_categorical_accuracy: 0.6540 - val_sparse_top_k_categorical_accuracy: 0.7909
# Epoch 4/500
# 49988/49988 - 5s - loss: 2.3486 - sparse_categorical_accuracy: 0.4380 - sparse_top_k_categorical_accuracy: 0.8115 - val_loss: 2.3281 - val_sparse_categorical_accuracy: 0.5161 - val_sparse_top_k_categorical_accuracy: 0.7141
# Epoch 5/500
# 49988/49988 - 5s - loss: 2.2306 - sparse_categorical_accuracy: 0.4409 - sparse_top_k_categorical_accuracy: 0.8138 - val_loss: 1.9877 - val_sparse_categorical_accuracy: 0.5926 - val_sparse_top_k_categorical_accuracy: 0.6995
# Epoch 6/500
# 49988/49988 - 5s - loss: 2.2330 - sparse_categorical_accuracy: 0.4440 - sparse_top_k_categorical_accuracy: 0.8206 - val_loss: 2.0618 - val_sparse_categorical_accuracy: 0.6276 - val_sparse_top_k_categorical_accuracy: 0.7755
# Epoch 7/500
# 49988/49988 - 5s - loss: 2.1888 - sparse_categorical_accuracy: 0.4459 - sparse_top_k_categorical_accuracy: 0.8205 - val_loss: 1.9966 - val_sparse_categorical_accuracy: 0.6228 - val_sparse_top_k_categorical_accuracy: 0.7566
# Epoch 8/500
# 49988/49988 - 5s - loss: 2.1778 - sparse_categorical_accuracy: 0.4470 - sparse_top_k_categorical_accuracy: 0.8214 - val_loss: 1.9228 - val_sparse_categorical_accuracy: 0.6081 - val_sparse_top_k_categorical_accuracy: 0.7266
# Epoch 9/500
# 49988/49988 - 5s - loss: 2.1449 - sparse_categorical_accuracy: 0.4514 - sparse_top_k_categorical_accuracy: 0.8228 - val_loss: 2.1942 - val_sparse_categorical_accuracy: 0.5412 - val_sparse_top_k_categorical_accuracy: 0.7118
# Epoch 10/500
# 49988/49988 - 5s - loss: 2.1386 - sparse_categorical_accuracy: 0.4497 - sparse_top_k_categorical_accuracy: 0.8259 - val_loss: 1.8719 - val_sparse_categorical_accuracy: 0.7424 - val_sparse_top_k_categorical_accuracy: 0.8366
# Epoch 11/500
# 49988/49988 - 5s - loss: 2.1469 - sparse_categorical_accuracy: 0.4519 - sparse_top_k_categorical_accuracy: 0.8268 - val_loss: 1.7791 - val_sparse_categorical_accuracy: 0.6273 - val_sparse_top_k_categorical_accuracy: 0.7688
# Epoch 12/500
# 49988/49988 - 5s - loss: 2.1687 - sparse_categorical_accuracy: 0.4489 - sparse_top_k_categorical_accuracy: 0.8249 - val_loss: 1.8773 - val_sparse_categorical_accuracy: 0.5905 - val_sparse_top_k_categorical_accuracy: 0.7093
# Epoch 13/500
# 49988/49988 - 5s - loss: 2.1060 - sparse_categorical_accuracy: 0.4514 - sparse_top_k_categorical_accuracy: 0.8264 - val_loss: 1.8368 - val_sparse_categorical_accuracy: 0.6164 - val_sparse_top_k_categorical_accuracy: 0.7540
# Epoch 14/500
# 49988/49988 - 5s - loss: 2.1199 - sparse_categorical_accuracy: 0.4537 - sparse_top_k_categorical_accuracy: 0.8260 - val_loss: 1.8002 - val_sparse_categorical_accuracy: 0.6298 - val_sparse_top_k_categorical_accuracy: 0.7881
# Epoch 15/500
# 49988/49988 - 5s - loss: 2.0845 - sparse_categorical_accuracy: 0.4520 - sparse_top_k_categorical_accuracy: 0.8271 - val_loss: 1.8496 - val_sparse_categorical_accuracy: 0.6070 - val_sparse_top_k_categorical_accuracy: 0.7317
# Epoch 16/500
# 49988/49988 - 5s - loss: 2.0719 - sparse_categorical_accuracy: 0.4524 - sparse_top_k_categorical_accuracy: 0.8274 - val_loss: 1.6721 - val_sparse_categorical_accuracy: 0.6696 - val_sparse_top_k_categorical_accuracy: 0.7951
# Epoch 17/500
# 49988/49988 - 5s - loss: 2.0949 - sparse_categorical_accuracy: 0.4510 - sparse_top_k_categorical_accuracy: 0.8297 - val_loss: 1.6754 - val_sparse_categorical_accuracy: 0.6259 - val_sparse_top_k_categorical_accuracy: 0.7925
# Epoch 18/500
# 49988/49988 - 5s - loss: 2.0776 - sparse_categorical_accuracy: 0.4520 - sparse_top_k_categorical_accuracy: 0.8299 - val_loss: 1.7247 - val_sparse_categorical_accuracy: 0.6476 - val_sparse_top_k_categorical_accuracy: 0.7629
# Epoch 19/500
# 49988/49988 - 5s - loss: 2.0701 - sparse_categorical_accuracy: 0.4548 - sparse_top_k_categorical_accuracy: 0.8289 - val_loss: 1.7317 - val_sparse_categorical_accuracy: 0.6178 - val_sparse_top_k_categorical_accuracy: 0.7282
# Epoch 20/500
# 49988/49988 - 5s - loss: 2.0390 - sparse_categorical_accuracy: 0.4559 - sparse_top_k_categorical_accuracy: 0.8310 - val_loss: 1.5694 - val_sparse_categorical_accuracy: 0.6831 - val_sparse_top_k_categorical_accuracy: 0.8060
# Epoch 21/500
# 49988/49988 - 5s - loss: 2.0405 - sparse_categorical_accuracy: 0.4587 - sparse_top_k_categorical_accuracy: 0.8309 - val_loss: 1.5714 - val_sparse_categorical_accuracy: 0.6463 - val_sparse_top_k_categorical_accuracy: 0.8024
# Epoch 22/500
# 49988/49988 - 5s - loss: 2.0607 - sparse_categorical_accuracy: 0.4560 - sparse_top_k_categorical_accuracy: 0.8295 - val_loss: 1.7167 - val_sparse_categorical_accuracy: 0.6117 - val_sparse_top_k_categorical_accuracy: 0.7610
# Epoch 23/500
# 49988/49988 - 5s - loss: 2.0207 - sparse_categorical_accuracy: 0.4570 - sparse_top_k_categorical_accuracy: 0.8337 - val_loss: 1.5484 - val_sparse_categorical_accuracy: 0.6573 - val_sparse_top_k_categorical_accuracy: 0.8164
# Epoch 24/500
# 49988/49988 - 5s - loss: 2.0376 - sparse_categorical_accuracy: 0.4547 - sparse_top_k_categorical_accuracy: 0.8313 - val_loss: 2.1896 - val_sparse_categorical_accuracy: 0.5012 - val_sparse_top_k_categorical_accuracy: 0.7262
# Epoch 25/500
# 49988/49988 - 5s - loss: 2.0455 - sparse_categorical_accuracy: 0.4571 - sparse_top_k_categorical_accuracy: 0.8306 - val_loss: 1.7031 - val_sparse_categorical_accuracy: 0.6385 - val_sparse_top_k_categorical_accuracy: 0.7975
# Epoch 26/500
# 49988/49988 - 5s - loss: 2.1214 - sparse_categorical_accuracy: 0.4509 - sparse_top_k_categorical_accuracy: 0.8289 - val_loss: 1.7203 - val_sparse_categorical_accuracy: 0.7067 - val_sparse_top_k_categorical_accuracy: 0.8244
# Epoch 27/500
# 49988/49988 - 5s - loss: 2.0535 - sparse_categorical_accuracy: 0.4550 - sparse_top_k_categorical_accuracy: 0.8311 - val_loss: 1.9591 - val_sparse_categorical_accuracy: 0.5899 - val_sparse_top_k_categorical_accuracy: 0.7110
# Epoch 28/500
# 49988/49988 - 5s - loss: 2.0411 - sparse_categorical_accuracy: 0.4575 - sparse_top_k_categorical_accuracy: 0.8316 - val_loss: 1.9384 - val_sparse_categorical_accuracy: 0.6080 - val_sparse_top_k_categorical_accuracy: 0.7828
# Epoch 29/500
# 49988/49988 - 5s - loss: 2.0736 - sparse_categorical_accuracy: 0.4576 - sparse_top_k_categorical_accuracy: 0.8303 - val_loss: 1.4656 - val_sparse_categorical_accuracy: 0.6637 - val_sparse_top_k_categorical_accuracy: 0.8381
# Epoch 30/500
# 49988/49988 - 5s - loss: 1.9964 - sparse_categorical_accuracy: 0.4596 - sparse_top_k_categorical_accuracy: 0.8314 - val_loss: 1.4887 - val_sparse_categorical_accuracy: 0.6748 - val_sparse_top_k_categorical_accuracy: 0.8220
# Epoch 31/500
# 49988/49988 - 5s - loss: 1.9756 - sparse_categorical_accuracy: 0.4613 - sparse_top_k_categorical_accuracy: 0.8347 - val_loss: 1.5283 - val_sparse_categorical_accuracy: 0.6651 - val_sparse_top_k_categorical_accuracy: 0.8109
# Epoch 32/500
# 49988/49988 - 5s - loss: 1.9836 - sparse_categorical_accuracy: 0.4634 - sparse_top_k_categorical_accuracy: 0.8347 - val_loss: 1.4605 - val_sparse_categorical_accuracy: 0.6954 - val_sparse_top_k_categorical_accuracy: 0.8356
# Epoch 33/500
# 49988/49988 - 5s - loss: 2.0780 - sparse_categorical_accuracy: 0.4607 - sparse_top_k_categorical_accuracy: 0.8316 - val_loss: 1.7879 - val_sparse_categorical_accuracy: 0.6004 - val_sparse_top_k_categorical_accuracy: 0.7399
# Epoch 34/500
# 49988/49988 - 5s - loss: 1.9895 - sparse_categorical_accuracy: 0.4635 - sparse_top_k_categorical_accuracy: 0.8338 - val_loss: 1.8504 - val_sparse_categorical_accuracy: 0.5943 - val_sparse_top_k_categorical_accuracy: 0.7737
# Epoch 35/500
# 49988/49988 - 5s - loss: 2.0083 - sparse_categorical_accuracy: 0.4633 - sparse_top_k_categorical_accuracy: 0.8339 - val_loss: 1.5598 - val_sparse_categorical_accuracy: 0.6522 - val_sparse_top_k_categorical_accuracy: 0.8264
# Epoch 36/500
# 49988/49988 - 5s - loss: 1.9510 - sparse_categorical_accuracy: 0.4685 - sparse_top_k_categorical_accuracy: 0.8353 - val_loss: 1.5181 - val_sparse_categorical_accuracy: 0.6516 - val_sparse_top_k_categorical_accuracy: 0.8041
# Epoch 37/500
# 49988/49988 - 5s - loss: 1.9475 - sparse_categorical_accuracy: 0.4713 - sparse_top_k_categorical_accuracy: 0.8365 - val_loss: 1.6438 - val_sparse_categorical_accuracy: 0.6184 - val_sparse_top_k_categorical_accuracy: 0.8197
# Epoch 38/500
# 49988/49988 - 5s - loss: 1.9518 - sparse_categorical_accuracy: 0.4709 - sparse_top_k_categorical_accuracy: 0.8392 - val_loss: 1.4435 - val_sparse_categorical_accuracy: 0.7406 - val_sparse_top_k_categorical_accuracy: 0.8624
# Epoch 39/500
# 49988/49988 - 5s - loss: 1.9515 - sparse_categorical_accuracy: 0.4726 - sparse_top_k_categorical_accuracy: 0.8368 - val_loss: 1.4643 - val_sparse_categorical_accuracy: 0.6869 - val_sparse_top_k_categorical_accuracy: 0.8228
# Epoch 40/500
# 49988/49988 - 5s - loss: 1.9316 - sparse_categorical_accuracy: 0.4735 - sparse_top_k_categorical_accuracy: 0.8389 - val_loss: 1.4533 - val_sparse_categorical_accuracy: 0.6763 - val_sparse_top_k_categorical_accuracy: 0.8408
# Epoch 41/500
# 49988/49988 - 5s - loss: 1.9328 - sparse_categorical_accuracy: 0.4739 - sparse_top_k_categorical_accuracy: 0.8388 - val_loss: 1.4166 - val_sparse_categorical_accuracy: 0.7320 - val_sparse_top_k_categorical_accuracy: 0.8450
# Epoch 42/500
# 49988/49988 - 5s - loss: 1.9524 - sparse_categorical_accuracy: 0.4705 - sparse_top_k_categorical_accuracy: 0.8383 - val_loss: 1.4789 - val_sparse_categorical_accuracy: 0.6858 - val_sparse_top_k_categorical_accuracy: 0.8286

# %%
hpo_ens.w_
